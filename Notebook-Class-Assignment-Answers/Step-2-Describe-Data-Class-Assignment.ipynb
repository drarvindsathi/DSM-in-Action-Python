# %%
import os
import pandas as pd
#import json
#from datetime import datetime
#from datetime import timedelta

# %%
using_Google_colab = False
using_Anaconda_on_Mac_or_Linux = True
using_Anaconda_on_windows = False

# %%
if using_Google_colab:
    from google.colab import drive
    drive.mount('/content/drive')

# %% [markdown]
# # DU1.1 		Open USA Facts Data Source and list data sets

# %%
if using_Google_colab:
  files_USA_Facts = os.listdir('/content/drive/MyDrive/COVID_Project/input/USA_Facts')
if using_Anaconda_on_Mac_or_Linux:
  files_USA_Facts = os.listdir("../input/USA_Facts")
if using_Anaconda_on_windows:
  files_USA_Facts = os.listdir(r"..\input\USA_Facts")
files_USA_Facts
# Out:
# ['Provisional_COVID-19_Death_Counts_by_Week_Ending_Date_and_State.csv',
#  'nursing_home_residents_usafacts.csv',
#  'percent_of_adults_with_asthma_usafacts.csv',
#  'confirmed_cases_by_state.csv',
#  'children_receiving_school_lunch_usafacts.csv',
#  'covid_deaths_usafacts.csv',
#  'people_in_food-insecure_households_usafacts.csv',
#  'covid_county_population_usafacts.csv',
#  'homeless_population_usafacts.csv',
#  'percent_of_adults_with_diabetes_usafacts.csv',
#  'incremental_cases_by_state.csv',
#  'covid_confirmed_usafacts.csv',
#  'households_usafacts.csv',
#  'covid_confirmed_usafacts.xlsx',
#  'Archive.zip',
#  'hospital_beds_usafacts.csv']

# %% [markdown]
# #   DU1.2		Understand number of files included in this data source

# %%
len(files_USA_Facts)
# Out:
# 16

# %% [markdown]
# # DU1.3		Repeat the same for next data source  - Owid-covid-global

# %%
if using_Google_colab:
  files_OWID_COVID = os.listdir('/content/drive/MyDrive/COVID_Project/input/OWID-COVID-Global')
if using_Anaconda_on_Mac_or_Linux:
  files_OWID_COVID = os.listdir("../input/OWID-COVID-Global")
if using_Anaconda_on_windows:
  files_USA_Facts = os.listdir(r"..\input\OWID-COVID-Global")
files_OWID_COVID
# Out:
# ['owid-covid-data.csv']

# %%
len(files_OWID_COVID)
# Out:
# 1

# %% [markdown]
# #  DU1.4		Repeat the same for next data source  - WHO-global

# %%
if using_Google_colab:
  files_WHO_Global = os.listdir('/content/drive/MyDrive/COVID_Project/input/WHO-Global')
if using_Anaconda_on_Mac_or_Linux:
  files_WHO_Global = os.listdir("../input/WHO-Global")
if using_Anaconda_on_windows:
  files_WHO_Global = os.listdir(r"..\input\WHO-Global")
files_WHO_Global
# Out:
# ['WHO-COVID-19-global-data.csv']

# %%
len(files_WHO_Global)
# Out:
# 1

# %% [markdown]
# # DU1.5		Repeat the same for next data source  - Google

# %%
if using_Google_colab:
  files_Google = os.listdir('/content/drive/MyDrive/COVID_Project/input/Google')
if using_Anaconda_on_Mac_or_Linux:
  files_Google = os.listdir("../input/Google")
if using_Anaconda_on_windows:
  files_Google = os.listdir(r"..\input\Google")
files_Google
# Out:
# ['.DS_Store',
#  'Region_Mobility_Report_CSVs.zip',
#  'Region_Mobility_Report_CSVs',
#  '2020_US_county_Symptom_dataset',
#  'locations.csv']

# %%
len(files_Google)
# Out:
# 5

# %% [markdown]
# #   DU2.1 		Open “covid_confirmed_usafacts” dataset file from USA Facts Data Source

# %%
if using_Google_colab:
  df_covid_confirmed = pd.read_csv('/content/drive/MyDrive/COVID_Project/input/USA_Facts/covid_confirmed_usafacts.csv')
if using_Anaconda_on_Mac_or_Linux:
  df_covid_confirmed = pd.read_csv("../input/USA_Facts/covid_confirmed_usafacts.csv")
if using_Anaconda_on_windows:
  df_covid_confirmed = pd.read_csv(r"..\input\USA_Facts\covid_confirmed_usafacts.csv")
df_covid_confirmed
# Out:
#       countyFIPS            County Name State  stateFIPS  1/22/20  1/23/20  \
# 0              0  Statewide Unallocated    AL          1        0        0
# 1           1001         Autauga County    AL          1        0        0
# 2           1003         Baldwin County    AL          1        0        0
# 3           1005         Barbour County    AL          1        0        0
# 4           1007            Bibb County    AL          1        0        0
# ...          ...                    ...   ...        ...      ...      ...
# 3190       56037      Sweetwater County    WY         56        0        0
# 3191       56039           Teton County    WY         56        0        0
# 3192       56041           Uinta County    WY         56        0        0
# 3193       56043        Washakie County    WY         56        0        0
# 3194       56045          Weston County    WY         56        0        0
#
# ...

# %% [markdown]
# # DU2.2		Review data types included in this  Data Set - “covid_confirmed_usafacts”

# %%
df_covid_confirmed.columns
# Out:
# Index(['countyFIPS', 'County Name', 'State', 'stateFIPS', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '12/11/20', '12/12/20', '12/13/20', '12/14/20', '12/15/20', '12/16/20',
#        '12/17/20', '12/18/20', '12/19/20', '12/20/20'],
#       dtype='object', length=338)

# %% [markdown]
# # DU2.3		Review data fields included in this  Data Set - “covid_confirmed_usafacts”

# %%
df_covid_confirmed.describe
# Out:
# <bound method NDFrame.describe of       countyFIPS            County Name State  stateFIPS  1/22/20  1/23/20  \
# 0              0  Statewide Unallocated    AL          1        0        0
# 1           1001         Autauga County    AL          1        0        0
# 2           1003         Baldwin County    AL          1        0        0
# 3           1005         Barbour County    AL          1        0        0
# 4           1007            Bibb County    AL          1        0        0
# ...          ...                    ...   ...        ...      ...      ...
# 3190       56037      Sweetwater County    WY         56        0        0
# 3191       56039           Teton County    WY         56        0        0
# 3192       56041           Uinta County    WY         56        0        0
# 3193       56043        Washakie County    WY         56        0        0
# 3194       56045          Weston County    WY         56        0        0
#
# ...

# %% [markdown]
# #  DU2.4		Get an estimates on total record size for this dataset - “covid_confirmed_usafacts”

# %%
df_covid_confirmed.shape
# Out:
# (3195, 338)

# %% [markdown]
# ## DU2.5 Repeat the same for other datasets  in this data sources - Let's use file "covid_deaths_usafacts.csv" file in USA_Facts - CLASS ASSIGNMENT

# %%
if using_Google_colab:
  df_covid_deaths = pd.read_csv('/content/drive/MyDrive/COVID_Project/input/USA_Facts/covid_deaths_usafacts.csv')
if using_Anaconda_on_Mac_or_Linux:
  df_covid_deaths = pd.read_csv("../input/USA_Facts/covid_deaths_usafacts.csv")
if using_Anaconda_on_windows:
  df_covid_deaths = pd.read_csv(r"..\input\USA_Facts\covid_deaths_usafacts.csv")
df_covid_deaths
# Out:
#       countyFIPS            County Name State  stateFIPS  1/22/20  1/23/20  \
# 0              0  Statewide Unallocated    AL          1        0        0
# 1           1001         Autauga County    AL          1        0        0
# 2           1003         Baldwin County    AL          1        0        0
# 3           1005         Barbour County    AL          1        0        0
# 4           1007            Bibb County    AL          1        0        0
# 5           1009          Blount County    AL          1        0        0
# 6           1011         Bullock County    AL          1        0        0
# 7           1013          Butler County    AL          1        0        0
# 8           1015         Calhoun County    AL          1        0        0
# 9           1017        Chambers County    AL          1        0        0
# 10          1019        Cherokee County    AL          1        0        0
# ...

# %%
df_covid_deaths.columns
# Out:
# Index(['countyFIPS', 'County Name', 'State', 'stateFIPS', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '12/11/20', '12/12/20', '12/13/20', '12/14/20', '12/15/20', '12/16/20',
#        '12/17/20', '12/18/20', '12/19/20', '12/20/20'],
#       dtype='object', length=338)

# %%
df_covid_deaths.describe
# Out:
# <bound method NDFrame.describe of       countyFIPS            County Name State  stateFIPS  1/22/20  1/23/20  \
# 0              0  Statewide Unallocated    AL          1        0        0
# 1           1001         Autauga County    AL          1        0        0
# 2           1003         Baldwin County    AL          1        0        0
# 3           1005         Barbour County    AL          1        0        0
# 4           1007            Bibb County    AL          1        0        0
# 5           1009          Blount County    AL          1        0        0
# 6           1011         Bullock County    AL          1        0        0
# 7           1013          Butler County    AL          1        0        0
# 8           1015         Calhoun County    AL          1        0        0
# 9           1017        Chambers County    AL          1        0        0
# 10          1019        Cherokee County    AL          1        0        0
# ...

# %% [markdown]
# ## DU2.6 If desired, above process can be repeated for other  data sources - Owid-covid-global - CLASS ASSIGMENT

# %%
if using_Google_colab:
  df_owid_covid_global = pd.read_csv('/content/drive/MyDrive/COVID_Project/input/OWID-COVID-Global/owid-covid-data.csv')
if using_Anaconda_on_Mac_or_Linux:
  df_owid_covid_global = pd.read_csv("../input/OWID-COVID-Global/owid-covid-data.csv")
if using_Anaconda_on_windows:
  df_owid_covid_global = pd.read_csv(r"..\input\OWID-COVID-Global/owid-covid-data.csv")
df_owid_covid_global
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  12/31/19          NaN        0.0
# 1          AFG      Asia    Afghanistan    1/1/20          NaN        0.0
# 2          AFG      Asia    Afghanistan    1/2/20          NaN        0.0
# 3          AFG      Asia    Afghanistan    1/3/20          NaN        0.0
# 4          AFG      Asia    Afghanistan    1/4/20          NaN        0.0
# 5          AFG      Asia    Afghanistan    1/5/20          NaN        0.0
# 6          AFG      Asia    Afghanistan    1/6/20          NaN        0.0
# 7          AFG      Asia    Afghanistan    1/7/20          NaN        0.0
# 8          AFG      Asia    Afghanistan    1/8/20          NaN        0.0
# 9          AFG      Asia    Afghanistan    1/9/20          NaN        0.0
# 10         AFG      Asia    Afghanistan   1/10/20          NaN        0.0
# 11         AFG      Asia    Afghanistan   1/11/20          NaN        0.0
# ...

# %%
df_owid_covid_global.describe
# Out:
# <bound method NDFrame.describe of       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  12/31/19          NaN        0.0
# 1          AFG      Asia    Afghanistan    1/1/20          NaN        0.0
# 2          AFG      Asia    Afghanistan    1/2/20          NaN        0.0
# 3          AFG      Asia    Afghanistan    1/3/20          NaN        0.0
# 4          AFG      Asia    Afghanistan    1/4/20          NaN        0.0
# 5          AFG      Asia    Afghanistan    1/5/20          NaN        0.0
# 6          AFG      Asia    Afghanistan    1/6/20          NaN        0.0
# 7          AFG      Asia    Afghanistan    1/7/20          NaN        0.0
# 8          AFG      Asia    Afghanistan    1/8/20          NaN        0.0
# 9          AFG      Asia    Afghanistan    1/9/20          NaN        0.0
# 10         AFG      Asia    Afghanistan   1/10/20          NaN        0.0
# ...

# %% [markdown]
# # DU3.1 		Classify data contents included in “covid_confirmed_usafacts” dataset file from USA Facts

# %%
df_covid_confirmed
# Out:
#       countyFIPS            County Name State  stateFIPS  1/22/20  1/23/20  \
# 0              0  Statewide Unallocated    AL          1        0        0
# 1           1001         Autauga County    AL          1        0        0
# 2           1003         Baldwin County    AL          1        0        0
# 3           1005         Barbour County    AL          1        0        0
# 4           1007            Bibb County    AL          1        0        0
# ...          ...                    ...   ...        ...      ...      ...
# 3190       56037      Sweetwater County    WY         56        0        0
# 3191       56039           Teton County    WY         56        0        0
# 3192       56041           Uinta County    WY         56        0        0
# 3193       56043        Washakie County    WY         56        0        0
# 3194       56045          Weston County    WY         56        0        0
#
# ...

# %% [markdown]
# ## DU3.2 Repeat the same for other datasets in this data sources (USA Facts) - covid_deaths_usafacts.csv - CLASS ASSIGNMENT

# %%
if using_Google_colab:
  df_covid_deaths = pd.read_csv('/content/drive/MyDrive/COVID_Project/input/USA_Facts/covid_deaths_usafacts.csv')
if using_Anaconda_on_Mac_or_Linux:
  df_covid_deaths = pd.read_csv("../input/USA_Facts/covid_deaths_usafacts.csv")
if using_Anaconda_on_windows:
  df_covid_deaths = pd.read_csv(r"..\input\USA_Facts\covid_deaths_usafacts.csv")
df_covid_deaths
# Out:
#       countyFIPS            County Name State  stateFIPS  1/22/20  1/23/20  \
# 0              0  Statewide Unallocated    AL          1        0        0
# 1           1001         Autauga County    AL          1        0        0
# 2           1003         Baldwin County    AL          1        0        0
# 3           1005         Barbour County    AL          1        0        0
# 4           1007            Bibb County    AL          1        0        0
# 5           1009          Blount County    AL          1        0        0
# 6           1011         Bullock County    AL          1        0        0
# 7           1013          Butler County    AL          1        0        0
# 8           1015         Calhoun County    AL          1        0        0
# 9           1017        Chambers County    AL          1        0        0
# 10          1019        Cherokee County    AL          1        0        0
# ...

# %% [markdown]
# ## DU3.2 Repeat the same for other datasets OWID-COVID-Global - CLASS ASSIGNMENT

# %%
if using_Google_colab:
  df_owid_covid_global = pd.read_csv('/content/drive/MyDrive/COVID_Project/input/OWID-COVID-Global/owid-covid-data.csv')
if using_Anaconda_on_Mac_or_Linux:
  df_owid_covid_global = pd.read_csv("../input/OWID-COVID-Global/owid-covid-data.csv")
if using_Anaconda_on_windows:
  df_owid_covid_global = pd.read_csv(r"..\input\OWID-COVID-Global/owid-covid-data.csv")
df_owid_covid_global

# %% [markdown]
# # DU4.1 		Determine basic statistics on “covid_confirmed_usafacts” dataset file from USA Facts Data Source

# %%
df_covid_confirmed.describe()
# Out:
#          countyFIPS    stateFIPS      1/22/20      1/23/20      1/24/20  \
# count   3195.000000  3195.000000  3195.000000  3195.000000  3195.000000
# mean   29882.221283    30.250391     0.000313     0.000313     0.000626
# std    15524.478700    15.159987     0.017691     0.017691     0.025016
# min        0.000000     1.000000     0.000000     0.000000     0.000000
# 25%    18098.000000    18.000000     0.000000     0.000000     0.000000
# 50%    29123.000000    29.000000     0.000000     0.000000     0.000000
# 75%    45054.000000    45.000000     0.000000     0.000000     0.000000
# max    56045.000000    56.000000     1.000000     1.000000     1.000000
#
#            1/25/20      1/26/20      1/27/20      1/28/20      1/29/20  ...  \
# count  3195.000000  3195.000000  3195.000000  3195.000000  3195.000000  ...
# mean      0.000626     0.001565     0.001878     0.001878     0.002191  ...
# std       0.025016     0.039535     0.043301     0.043301     0.053038  ...
# ...

# %% [markdown]
# # DU5.1 Open “covid_confirmed_usafacts” dataset file from USA Facts Data Source and determine number of missing value

# %%
df_covid_confirmed
# Out:
#       countyFIPS            County Name State  stateFIPS  1/22/20  1/23/20  \
# 0              0  Statewide Unallocated    AL          1        0        0
# 1           1001         Autauga County    AL          1        0        0
# 2           1003         Baldwin County    AL          1        0        0
# 3           1005         Barbour County    AL          1        0        0
# 4           1007            Bibb County    AL          1        0        0
# ...          ...                    ...   ...        ...      ...      ...
# 3190       56037      Sweetwater County    WY         56        0        0
# 3191       56039           Teton County    WY         56        0        0
# 3192       56041           Uinta County    WY         56        0        0
# 3193       56043        Washakie County    WY         56        0        0
# 3194       56045          Weston County    WY         56        0        0
#
# ...

# %% [markdown]
# # DU5.1 Open “covid_confirmed_usafacts” dataset file from USA Facts Data Source and determine Total number of records and number of records with no value

# %%
statevars = ['countyFIPS', 'County Name', 'State', 'stateFIPS']

# %%
df_covid_confirmed[statevars].isnull().sum(axis=0)
# Out:
# countyFIPS     0
# County Name    0
# State          0
# stateFIPS      0
# dtype: int64

# %% [markdown]
# # DU5.2	 Verify data quality issues for OWID-COVID-Global data source

# %%
if using_Google_colab:
  df_OWID_COVID_Global = pd.read_csv('/content/drive/MyDrive/COVID_Project/input/OWID-COVID-Global/owid-covid-data.csv')
if using_Anaconda_on_Mac_or_Linux:
  df_OWID_COVID_Global = pd.read_csv("../input/OWID-COVID-Global/owid-covid-data.csv")
if using_Anaconda_on_windows:
  df_OWID_COVID_Global = pd.read_csv(r"..\input\OWID-COVID-Global\owid-covid-data.csv")
df_OWID_COVID_Global
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  12/31/19          NaN        0.0
# 1          AFG      Asia    Afghanistan    1/1/20          NaN        0.0
# 2          AFG      Asia    Afghanistan    1/2/20          NaN        0.0
# 3          AFG      Asia    Afghanistan    1/3/20          NaN        0.0
# 4          AFG      Asia    Afghanistan    1/4/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 53952      NaN       NaN  International  10/28/20        696.0        NaN
# 53953      NaN       NaN  International  10/29/20        696.0        NaN
# 53954      NaN       NaN  International  10/30/20        696.0        NaN
# 53955      NaN       NaN  International  10/31/20        696.0        NaN
# 53956      NaN       NaN  International   11/1/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  Death / per capita  new_deaths  ...  \
# ...

# %%
df_OWID_COVID_Global.shape
# Out:
# (53957, 54)

# %%
df_OWID_COVID_Global.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'Death / per capita',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'Total deaths per million', 'Unnamed: 37', 'population.1',
# ...

# %%
df_OWID_COVID_Global
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  12/31/19          NaN        0.0
# 1          AFG      Asia    Afghanistan    1/1/20          NaN        0.0
# 2          AFG      Asia    Afghanistan    1/2/20          NaN        0.0
# 3          AFG      Asia    Afghanistan    1/3/20          NaN        0.0
# 4          AFG      Asia    Afghanistan    1/4/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 53952      NaN       NaN  International  10/28/20        696.0        NaN
# 53953      NaN       NaN  International  10/29/20        696.0        NaN
# 53954      NaN       NaN  International  10/30/20        696.0        NaN
# 53955      NaN       NaN  International  10/31/20        696.0        NaN
# 53956      NaN       NaN  International   11/1/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  Death / per capita  new_deaths  ...  \
# ...

# %%
df_OWID_COVID_Global.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.033000e+04   53045.000000         52247.00000  4.128300e+04
# mean   1.469059e+05    1740.178773          1708.91144  6.362527e+03
# std    1.473997e+06   15873.433805         15427.51208  5.148749e+04
# min    1.000000e+00   -8261.000000          -552.00000  1.000000e+00
# 25%    1.530000e+02       0.000000             0.71400  1.100000e+01
# 50%    1.847000e+03      13.000000            18.00000  7.700000e+01
# 75%    1.875500e+04     209.000000           217.57100  6.470000e+02
# max    4.615654e+07  545816.000000        482844.00000  1.196272e+06
#
#        Death / per capita    new_deaths  new_deaths_smoothed  \
# count          210.000000  53045.000000         52247.000000
# mean           145.493394     45.100820            44.996832
# std            217.322155    374.785516           363.423138
# min              0.000000  -1918.000000          -232.143000
# ...

# %%
locationvars = ['iso_code', 'continent', 'location', 'gdp_per_capita', 'hospital_beds_per_thousand']

# %%
df_OWID_COVID_Global[locationvars].isnull().sum(axis=0)
# Out:
# iso_code                       307
# continent                      614
# location                         0
# gdp_per_capita                5951
# hospital_beds_per_thousand    7619
# dtype: int64

# %% [markdown]
# # Test code for finding missing data

# %%
if using_Google_colab:
  covidtotals = pd.read_csv('/content/drive/MyDrive/COVID_Project/input/TestFolder/COVIDTotalswithmissings.csv')
if using_Anaconda_on_Mac_or_Linux:
  covidtotals = pd.read_csv("../input/TestFolder/covidtotalswithmissings.csv")
if using_Anaconda_on_windows:
  covidtotals = pd.read_csv(r"..\input\TestFolder\covidtotalswithmissings.csv")
covidtotals
# Out:
#     iso_code lastdate        location  total_cases  total_deaths  \
# 0        AFG   6/1/20     Afghanistan        15205           257
# 1        ALB   6/1/20         Albania         1137            33
# 2        DZA   6/1/20         Algeria         9394           653
# 3        AND   6/1/20         Andorra          764            51
# 4        AGO   6/1/20          Angola           86             4
# ..       ...      ...             ...          ...           ...
# 205      VNM   6/1/20         Vietnam          328             0
# 206      ESH   6/1/20  Western Sahara           23             1
# 207      YEM   6/1/20           Yemen          323            80
# 208      ZMB   6/1/20          Zambia         1057             7
# 209      ZWE   6/1/20        Zimbabwe          178             4
#
#      total_cases_pm  total_deaths_pm  population  pop_density  median_age  \
# 0           390.589            6.602    38928341       54.422        18.6
# ...

# %%
totvars = ['location','total_cases','total_deaths','total_cases_pm','total_deaths_pm']

# %%
demovars = ['population','pop_density','median_age','gdp_per_capita','hosp_beds']

# %%
covidtotals[demovars].isnull().sum(axis=0)
# Out:
# population         0
# pop_density       12
# median_age        24
# gdp_per_capita    28
# hosp_beds         46
# dtype: int64

# %%
demovarsmisscnt = covidtotals[demovars].isnull().sum(axis=1)

# %%
demovarsmisscnt.value_counts()
# Out:
# 0    156
# 1     24
# 2     12
# 3     10
# 4      8
# dtype: int64
