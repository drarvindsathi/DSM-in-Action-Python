# %%
import os
import pandas as pd

# %%
using_Google_colab = False
using_Anaconda_on_Mac_or_Linux = True
using_Anaconda_on_windows = False

# %%
if using_Google_colab:
    from google.colab import drive
    drive.mount('/content/drive')

# %% [markdown]
# # PD 1.1 and PD 2.1 Open Notebook titled “Select_and_filter_operation”

# %% [markdown]
# Read file

# %%
df_google_mobility_data = pd.read_csv('../input/Google/Region_Mobility_Report_CSVs/2020_US_Region_Mobility_Report.csv')
df_google_mobility_data
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 0                       US  United States          NaN            NaN
# 1                       US  United States          NaN            NaN
# 2                       US  United States          NaN            NaN
# 3                       US  United States          NaN            NaN
# 4                       US  United States          NaN            NaN
# 5                       US  United States          NaN            NaN
# 6                       US  United States          NaN            NaN
# 7                       US  United States          NaN            NaN
# 8                       US  United States          NaN            NaN
# 9                       US  United States          NaN            NaN
# 10                      US  United States          NaN            NaN
# 11                      US  United States          NaN            NaN
# ...

# %%
df_google_mobility_data.columns
# Out:
# Index(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
#        'metro_area', 'iso_3166_2_code', 'census_fips_code', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %% [markdown]
# Select 'sub_region_1','census_fips_code', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'

# %%
df_google_mobility_data_selected = df_google_mobility_data[['sub_region_1','census_fips_code', 'date',
                                                             'retail_and_recreation_percent_change_from_baseline',
                                                             'grocery_and_pharmacy_percent_change_from_baseline',
                                                             'parks_percent_change_from_baseline',
                                                             'transit_stations_percent_change_from_baseline',
                                                             'workplaces_percent_change_from_baseline',
                                                             'residential_percent_change_from_baseline']]
                                              
df_google_mobility_data_selected
# Out:
#        sub_region_1  census_fips_code        date  \
# 0               NaN               NaN  2020-02-15
# 1               NaN               NaN  2020-02-16
# 2               NaN               NaN  2020-02-17
# 3               NaN               NaN  2020-02-18
# 4               NaN               NaN  2020-02-19
# 5               NaN               NaN  2020-02-20
# 6               NaN               NaN  2020-02-21
# 7               NaN               NaN  2020-02-22
# 8               NaN               NaN  2020-02-23
# 9               NaN               NaN  2020-02-24
# 10              NaN               NaN  2020-02-25
# 11              NaN               NaN  2020-02-26
# 12              NaN               NaN  2020-02-27
# 13              NaN               NaN  2020-02-28
# 14              NaN               NaN  2020-02-29
# 15              NaN               NaN  2020-03-01
# 16              NaN               NaN  2020-03-02
# 17              NaN               NaN  2020-03-03
# ...

# %%
df_google_mobility_data_selected = df_google_mobility_data_selected.rename(columns={"census_fips_code": "countyFIPS"})
df_google_mobility_data_selected
# Out:
#        sub_region_1  countyFIPS        date  \
# 0               NaN         NaN  2020-02-15
# 1               NaN         NaN  2020-02-16
# 2               NaN         NaN  2020-02-17
# 3               NaN         NaN  2020-02-18
# 4               NaN         NaN  2020-02-19
# 5               NaN         NaN  2020-02-20
# 6               NaN         NaN  2020-02-21
# 7               NaN         NaN  2020-02-22
# 8               NaN         NaN  2020-02-23
# 9               NaN         NaN  2020-02-24
# 10              NaN         NaN  2020-02-25
# 11              NaN         NaN  2020-02-26
# 12              NaN         NaN  2020-02-27
# 13              NaN         NaN  2020-02-28
# 14              NaN         NaN  2020-02-29
# 15              NaN         NaN  2020-03-01
# 16              NaN         NaN  2020-03-02
# 17              NaN         NaN  2020-03-03
# 18              NaN         NaN  2020-03-04
# 19              NaN         NaN  2020-03-05
# ...

# %%
df_google_mobility_data_selected.columns
# Out:
# Index(['sub_region_1', 'countyFIPS', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %% [markdown]
# # PD2.2 Start with the DataFrame you created in the previous section.  Select data for 24th December

# %%
df_christmas_eve = df_google_mobility_data_selected[df_google_mobility_data_selected.date == "2020-12-24"]
df_christmas_eve
# Out:
#        sub_region_1  countyFIPS        date  \
# 313             NaN         NaN  2020-12-24
# 628         Alabama         NaN  2020-12-24
# 937         Alabama      1001.0  2020-12-24
# 1252        Alabama      1003.0  2020-12-24
# 1542        Alabama      1005.0  2020-12-24
# 1832        Alabama      1007.0  2020-12-24
# 2141        Alabama      1009.0  2020-12-24
# 2363        Alabama      1011.0  2020-12-24
# 2653        Alabama      1013.0  2020-12-24
# 2968        Alabama      1015.0  2020-12-24
# 3277        Alabama      1017.0  2020-12-24
# 3567        Alabama      1019.0  2020-12-24
# 3876        Alabama      1021.0  2020-12-24
# 4098        Alabama      1023.0  2020-12-24
# 4388        Alabama      1025.0  2020-12-24
# 4611        Alabama      1027.0  2020-12-24
# 4881        Alabama      1029.0  2020-12-24
# 5190        Alabama      1031.0  2020-12-24
# 5499        Alabama      1033.0  2020-12-24
# 5787        Alabama      1035.0  2020-12-24
# ...

# %%
df_christmas_eve[df_christmas_eve.retail_and_recreation_percent_change_from_baseline > 30.0]
# Out:
#        sub_region_1  countyFIPS        date  \
# 74207      Colorado      8083.0  2020-12-24
# 397694     Missouri     29109.0  2020-12-24
# 410181     Missouri     29213.0  2020-12-24
# 634114    Tennessee     47155.0  2020-12-24
#
#         retail_and_recreation_percent_change_from_baseline  \
# 74207                                                31.0
# 397694                                               32.0
# 410181                                               39.0
# 634114                                               35.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 74207                                                 NaN
# 397694                                                NaN
# 410181                                               88.0
# 634114                                               63.0
#
#         parks_percent_change_from_baseline  \
# 74207                                  NaN
# 397694                                 NaN
# ...

# %% [markdown]
# # PD2.3	Open owid-covid-data.csv, Start with  DataFrame you created, Select data with population less than 10 million - CLASS ASSIGNMENT

# %%
df_owid_covid_data = pd.read_csv('../input/OWID-COVID-Global/owid-covid-data.csv')
df_owid_covid_data
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  12/31/19          NaN        0.0
# 1          AFG      Asia    Afghanistan    1/1/20          NaN        0.0
# 2          AFG      Asia    Afghanistan    1/2/20          NaN        0.0
# 3          AFG      Asia    Afghanistan    1/3/20          NaN        0.0
# 4          AFG      Asia    Afghanistan    1/4/20          NaN        0.0
# 5          AFG      Asia    Afghanistan    1/5/20          NaN        0.0
# 6          AFG      Asia    Afghanistan    1/6/20          NaN        0.0
# 7          AFG      Asia    Afghanistan    1/7/20          NaN        0.0
# 8          AFG      Asia    Afghanistan    1/8/20          NaN        0.0
# 9          AFG      Asia    Afghanistan    1/9/20          NaN        0.0
# 10         AFG      Asia    Afghanistan   1/10/20          NaN        0.0
# 11         AFG      Asia    Afghanistan   1/11/20          NaN        0.0
# ...

# %%
df_owid_covid_data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'Death / per capita',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'Total deaths per million', 'Unnamed: 37', 'population.1',
# ...

# %%
df_owid_covid_data_selected = df_owid_covid_data [['iso_code', 'location', 'date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'population']]

# %%
df_owid_covid_data_selected
# Out:
#       iso_code       location      date  total_cases  new_cases  total_deaths  \
# 0          AFG    Afghanistan  12/31/19          NaN        0.0           NaN
# 1          AFG    Afghanistan    1/1/20          NaN        0.0           NaN
# 2          AFG    Afghanistan    1/2/20          NaN        0.0           NaN
# 3          AFG    Afghanistan    1/3/20          NaN        0.0           NaN
# 4          AFG    Afghanistan    1/4/20          NaN        0.0           NaN
# 5          AFG    Afghanistan    1/5/20          NaN        0.0           NaN
# 6          AFG    Afghanistan    1/6/20          NaN        0.0           NaN
# 7          AFG    Afghanistan    1/7/20          NaN        0.0           NaN
# 8          AFG    Afghanistan    1/8/20          NaN        0.0           NaN
# 9          AFG    Afghanistan    1/9/20          NaN        0.0           NaN
# 10         AFG    Afghanistan   1/10/20          NaN        0.0           NaN
# ...

# %%
df_owid_covid_data_selected.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'population'],
#       dtype='object')

# %%
df_owid_covid_data_selected = df_owid_covid_data_selected.rename(columns={"location" : "country"})

# %%
df_covid_population_lt_10million = df_owid_covid_data_selected[df_owid_covid_data_selected['population'] < 10000000]

# %%
df_covid_population_lt_10million
# Out:
#       iso_code         country      date  total_cases  new_cases  \
# 307        ALB         Albania    3/9/20          2.0        2.0
# 308        ALB         Albania   3/10/20          6.0        4.0
# 309        ALB         Albania   3/11/20         10.0        4.0
# 310        ALB         Albania   3/12/20         11.0        1.0
# 311        ALB         Albania   3/13/20         23.0       12.0
# 312        ALB         Albania   3/14/20         33.0       10.0
# 313        ALB         Albania   3/15/20         38.0        5.0
# 314        ALB         Albania   3/16/20         42.0        4.0
# 315        ALB         Albania   3/17/20         51.0        9.0
# 316        ALB         Albania   3/18/20         55.0        4.0
# 317        ALB         Albania   3/19/20         59.0        4.0
# 318        ALB         Albania   3/20/20         70.0       11.0
# 319        ALB         Albania   3/21/20         70.0        0.0
# ...
