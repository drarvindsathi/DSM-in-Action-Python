# %% [markdown]
# # Step 4 – Develop Model - Task 1. Prediction Setup - CLASS ASSIGNMENT

# %% [markdown]
# ### Load Libraries

# %%
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Set up environment and connect to Google Drive

# %%
using_Google_colab = False
using_Anaconda_on_Mac_or_Linux = True
using_Anaconda_on_windows = False

# %%
if using_Google_colab:
    from google.colab import drive
    drive.mount('/content/drive')

# %% [markdown]
# ## DM1.1 Open Notebook titled “Step-4-Develop-Model-Task-1-Prediction-setup” and upload the state data, organizing by date while replacing empty cells with zeros - Activities 1 and 2

# %% [markdown]
# ### Upload State level Data

# %%
if using_Google_colab:
    df_abt_by_state = pd.read_csv('/content/drive/MyDrive/COVID_Project/output/abt_by_state.csv',
                                  index_col=['Date'], parse_dates=['Date'])
if using_Anaconda_on_Mac_or_Linux:
    df_abt_by_state = pd.read_csv('../output/abt_by_state.csv',
                                  index_col=['Date'], parse_dates=['Date'])
if using_Anaconda_on_windows:
    df_abt_by_state = pd.read_csv('..\output\abt_by_state.csv',
                                  index_col=['Date'], parse_dates=['Date'])
df_abt_by_state
# Out:
#             Unnamed: 0 State  stateFIPS  Total Cases  Incremental Cases  \
# Date
# 2020-01-22           0    AL          1            0                NaN
# 2020-01-23           1    AL          1            0                0.0
# 2020-01-24           2    AL          1            0                0.0
# 2020-01-25           3    AL          1            0                0.0
# 2020-01-26           4    AL          1            0                0.0
# 2020-01-27           5    AL          1            0                0.0
# 2020-01-28           6    AL          1            0                0.0
# 2020-01-29           7    AL          1            0                0.0
# 2020-01-30           8    AL          1            0                0.0
# 2020-01-31           9    AL          1            0                0.0
# 2020-02-01          10    AL          1            0                0.0
# 2020-02-02          11    AL          1            0                0.0
# ...

# %% [markdown]
# ### Filter Data to a specific state (e.g., NJ)

# %%
df_abt_chosen_state = df_abt_by_state[df_abt_by_state['State'] == 'NJ']
df_abt_chosen_state = df_abt_chosen_state.dropna()
df_abt_chosen_state
# Out:
#             Unnamed: 0 State  stateFIPS  Total Cases  Incremental Cases  \
# Date
# 2020-01-29        8357    NJ         34            0                0.0
# 2020-01-30        8358    NJ         34            0                0.0
# 2020-01-31        8359    NJ         34            0                0.0
# 2020-02-01        8360    NJ         34            0                0.0
# 2020-02-02        8361    NJ         34            0                0.0
# 2020-02-03        8362    NJ         34            0                0.0
# 2020-02-04        8363    NJ         34            0                0.0
# 2020-02-05        8364    NJ         34            0                0.0
# 2020-02-06        8365    NJ         34            0                0.0
# 2020-02-07        8366    NJ         34            0                0.0
# 2020-02-08        8367    NJ         34            0                0.0
# 2020-02-09        8368    NJ         34            0                0.0
# ...

# %% [markdown]
# ### DM 1.2 -  Activity 3: Select incremental cases and incremental deaths columns respectively as series, find their max and normalize.

# %%
state_covid_cases = df_abt_chosen_state['Incremental Cases']
cases_max = state_covid_cases.max()
state_covid_cases = state_covid_cases/cases_max
state_covid_deaths = df_abt_chosen_state['Incremental Deaths']
deaths_max = state_covid_deaths.max()
state_covid_deaths = state_covid_deaths / deaths_max

# %% [markdown]
# ### DM1.3 - Visualize the data and make observations
# ### Activity 4 - Plot Incremental Cases and Incremental Deaths

# %%
plt.figure(figsize=(17,8))
plt.title('Comparing cases and deaths over time')
plt.ylabel('Incremental Cases and Deaths')
plt.xlabel('day')
plt.plot(state_covid_cases, 'b', label='incremental cases')
plt.plot(state_covid_deaths, 'r', label='incremental deaths')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ### DM1.4  - Activity 5 - Compute 7 days and 30 days moving averages and visualize cross over points

# %%
state_covid_cases_ewm_7 = state_covid_cases.ewm(span=7, adjust= False).mean()
state_covid_deaths_ewm_7 = state_covid_deaths.ewm(span=7, adjust=False).mean()
state_covid_cases_ewm_30 = state_covid_cases.ewm(span=30, adjust= False).mean()
state_covid_deaths_ewm_30 = state_covid_deaths.ewm(span=30, adjust=False).mean()

# %% [markdown]
# ### DM1.4 - Activity 5 - Plot 30 days average

# %%
plt.figure(figsize=(17,8))
plt.title('Comparing cases and deaths using 30 days rolling means')
plt.ylabel('Incremental Cases and Deaths')
plt.xlabel('day')
plt.plot(state_covid_cases_ewm_30, 'b', label='30 days rolling mean incremental cases')
plt.plot(state_covid_deaths_ewm_30, 'r', label='30 days rolling mean incremental deaths')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### DM1.4 - Activity 6 - Compare 7 days and 30 days averages to identify cross over points

# %%
plt.figure(figsize=(17,8))
plt.title('Comparing cases with 7 days and 30 days rolling means')
plt.ylabel('Incremental Cases')
plt.xlabel('day')
#plt.plot(normalized_state_covid_cases, 'b', label='incremental cases')
plt.plot(state_covid_cases_ewm_7, 'r', label='7 days rolling mean incremental cases')
plt.plot(state_covid_cases_ewm_30, 'c', label='30 days rolling mean incremental cases')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Activity 6: Compute delta between 7 days and 30 days - Compute MACD

# %%
delta_cases = state_covid_cases_ewm_7 - state_covid_cases_ewm_30

# %%
plt.figure(figsize=(17,8))
plt.title('Plot MACD (Moving Average Convergence / Divergence')
plt.ylabel('MACD cases')
plt.xlabel('day')
plt.plot(delta_cases, 'r', label='Delta Cases')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ## DM1.5 Create a composite social mobility attribute (Class Assignment)

# %% [markdown]
# ## Upload County Level Google Mobility Data

# %%
if using_Google_colab:
    df_abt_by_county = pd.read_csv('/content/drive/MyDrive/COVID_Project/output/abt_by_county.csv',
                                  index_col=['Date'], parse_dates=['Date'])
if using_Anaconda_on_Mac_or_Linux:
    df_abt_by_county = pd.read_csv('../output/abt_by_county.csv',
                                  index_col=['Date'], parse_dates=['Date'])
if using_Anaconda_on_windows:
    df_abt_by_county = pd.read_csv('..\output\abt_by_county.csv',
                                  index_col=['Date'], parse_dates=['Date'])
df_abt_by_county
# Out:
#             Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1     County Name  \
# Date
# 2020-01-22           0             0             334     Kent County
# 2020-01-23           1             1             335     Kent County
# 2020-01-24           2             2             336     Kent County
# 2020-01-25           3             3             337     Kent County
# 2020-01-26           4             4             338     Kent County
# 2020-01-27           5             5             339     Kent County
# 2020-01-28           6             6             340     Kent County
# 2020-01-29           7             7             341     Kent County
# 2020-01-30           8             8             342     Kent County
# 2020-01-31           9             9             343     Kent County
# 2020-02-01          10            10             344     Kent County
# 2020-02-02          11            11             345     Kent County
# ...

# %% [markdown]
# ## Filter data to a specific county of state (e.g. Los Angeles County in CA)

# %%
df_abt_chosen_state_GM = df_abt_by_county[df_abt_by_county['County Name'] == 'Los Angeles County']
# df_abt_chosen_state_GM = df_abt_chosen_state_GM.dropna()
df_abt_chosen_state_GM
# Out:
#             Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1         County Name  \
# Date
# 2020-01-22     1012688       1012688         1013022  Los Angeles County
# 2020-01-23     1012689       1012689         1013023  Los Angeles County
# 2020-01-24     1012690       1012690         1013024  Los Angeles County
# 2020-01-25     1012691       1012691         1013025  Los Angeles County
# 2020-01-26     1012692       1012692         1013026  Los Angeles County
# 2020-01-27     1012693       1012693         1013027  Los Angeles County
# 2020-01-28     1012694       1012694         1013028  Los Angeles County
# 2020-01-29     1012695       1012695         1013029  Los Angeles County
# 2020-01-30     1012696       1012696         1013030  Los Angeles County
# 2020-01-31     1012697       1012697         1013031  Los Angeles County
# 2020-02-01     1012698       1012698         1013032  Los Angeles County
# 2020-02-02     1012699       1012699         1013033  Los Angeles County
# ...

# %%
df_abt_chosen_state_GM.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'County Name',
#        'countyFIPS', 'State', 'stateFIPS', 'Total Cases', 'Incremental Cases',
#        'cases moving_average', 'Total Deaths', 'Incremental Deaths',
#        'death moving_average', 'population', 'country_region_code',
#        'country_region', 'sub_region_1', 'sub_region_2', 'metro_area',
#        'iso_3166_2_code', 'census_fips_code', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %%
df_GM_score = df_abt_chosen_state_GM [['Incremental Cases','date', 
       'retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']]

# %%
df_GM_score
# Out:
#             Incremental Cases        date  \
# Date
# 2020-01-22                NaN         NaN
# 2020-01-23                0.0         NaN
# 2020-01-24                0.0         NaN
# 2020-01-25                0.0         NaN
# 2020-01-26                1.0         NaN
# 2020-01-27                0.0         NaN
# 2020-01-28                0.0         NaN
# 2020-01-29                0.0         NaN
# 2020-01-30                0.0         NaN
# 2020-01-31                0.0         NaN
# 2020-02-01                0.0         NaN
# 2020-02-02                0.0         NaN
# 2020-02-03                0.0         NaN
# 2020-02-04                0.0         NaN
# 2020-02-05                0.0         NaN
# 2020-02-06                0.0         NaN
# 2020-02-07                0.0         NaN
# 2020-02-08                0.0         NaN
# 2020-02-09                0.0         NaN
# 2020-02-10                0.0         NaN
# 2020-02-11                0.0         NaN
# ...

# %% [markdown]
# ## Drop NaN records

# %%
df_GM_score = df_GM_score.dropna()

# %%
df_GM_score
# Out:
#             Incremental Cases        date  \
# Date
# 2020-02-15                0.0  2020-02-15
# 2020-02-16                0.0  2020-02-16
# 2020-02-17                0.0  2020-02-17
# 2020-02-18                0.0  2020-02-18
# 2020-02-19                0.0  2020-02-19
# 2020-02-20                0.0  2020-02-20
# 2020-02-21                0.0  2020-02-21
# 2020-02-22                0.0  2020-02-22
# 2020-02-23                0.0  2020-02-23
# 2020-02-24                0.0  2020-02-24
# 2020-02-25                0.0  2020-02-25
# 2020-02-26                0.0  2020-02-26
# 2020-02-27                0.0  2020-02-27
# 2020-02-28                0.0  2020-02-28
# 2020-02-29                0.0  2020-02-29
# 2020-03-01                0.0  2020-03-01
# 2020-03-02                0.0  2020-03-02
# 2020-03-03                0.0  2020-03-03
# 2020-03-04                6.0  2020-03-04
# 2020-03-05                4.0  2020-03-05
# 2020-03-06                2.0  2020-03-06
# ...

# %%
df_GM_score = df_GM_score.rename(columns={"retail_and_recreation_percent_change_from_baseline": "GM1"})

# %%
df_GM_score = df_GM_score.rename(columns={"grocery_and_pharmacy_percent_change_from_baseline": "GM2"})

# %%
df_GM_score = df_GM_score.rename(columns={"parks_percent_change_from_baseline": "GM3"})

# %%
df_GM_score = df_GM_score.rename(columns={"transit_stations_percent_change_from_baseline": "GM4"})

# %%
df_GM_score = df_GM_score.rename(columns={"workplaces_percent_change_from_baseline": "GM5"})

# %%
df_GM_score = df_GM_score.rename(columns={"residential_percent_change_from_baseline": "GM6"})

# %%
df_GM_score
# Out:
#             Incremental Cases        date   GM1   GM2   GM3   GM4   GM5   GM6
# Date
# 2020-02-15                0.0  2020-02-15   1.0   0.0  13.0  -1.0  -1.0   0.0
# 2020-02-16                0.0  2020-02-16   4.0  -1.0  27.0  -1.0   0.0  -1.0
# 2020-02-17                0.0  2020-02-17   7.0   0.0  30.0 -11.0 -32.0   7.0
# 2020-02-18                0.0  2020-02-18  -1.0   0.0  11.0   2.0   2.0   0.0
# 2020-02-19                0.0  2020-02-19  -1.0  -1.0  13.0   1.0   2.0   0.0
# 2020-02-20                0.0  2020-02-20   1.0   0.0  11.0   2.0   2.0  -1.0
# 2020-02-21                0.0  2020-02-21   1.0   0.0   7.0   0.0   2.0   0.0
# 2020-02-22                0.0  2020-02-22  -1.0  -1.0 -13.0  -5.0   1.0   1.0
# 2020-02-23                0.0  2020-02-23   4.0   1.0  13.0   0.0   2.0   0.0
# 2020-02-24                0.0  2020-02-24   1.0  -1.0   8.0   2.0   4.0  -1.0
# 2020-02-25                0.0  2020-02-25   2.0   1.0  13.0   3.0   3.0  -1.0
# ...

# %%
df_GM_score['composite_score'] = df_GM_score['GM1'] + df_GM_score['GM2'] + df_GM_score['GM3'] + df_GM_score['GM4'] + df_GM_score['GM5'] + df_GM_score['GM6']

# %% [markdown]
# ## DM1.6 	Visualize composite social mobility attribute and its relationship with new cases (Class Assignment)

# %% [markdown]
# ## Let's plot Incremental cases first

# %%
plt.figure(figsize=(17,8))
plt.title('Comparing Mobility with Incremental Cases')
plt.ylabel('Incremental Cases')
plt.xlabel('day')
plt.plot(df_GM_score['composite_score'], 'r', label='Composite Mobility')
#plt.plot(df_GM_score['Incremental_cases'], 'c', label='Incremental Cases')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Let's plot both

# %%
plt.figure(figsize=(17,8))
plt.title('Comparing Mobility with Incremental Cases')
plt.ylabel('Incremental Cases')
plt.xlabel('day')
plt.plot(df_GM_score['composite_score'], 'r', label='Composite Mobility')
plt.plot(df_GM_score['Incremental Cases'], 'c', label='Incremental Cases')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Looks like scale for each is different, let's first normalize both variables and then plot then

# %%
LA_covid_cases = df_GM_score['Incremental Cases']
cases_max = LA_covid_cases.max()
LA_covid_cases = LA_covid_cases/cases_max
LA_GM_score = df_GM_score['composite_score']
GM_max = LA_GM_score.max() 
LA_GM_score = LA_GM_score/GM_max

# %%
plt.figure(figsize=(17,8))
plt.title('Comparing Incremental Cases and Mobility Composite Score over time')
plt.ylabel('Incremental Cases')
plt.xlabel('day')
plt.plot(LA_covid_cases, 'b', label='incremental cases')
plt.plot(LA_GM_score, 'r', label='Composite Mobility')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()
