# %% [markdown]
# # Step 4 – Develop Model - Task 1. Prediction Setup

# %% [markdown]
# ### Load Libraries

# %%
import os
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Set up environment and connect to Google Drive

# %%
using_Google_colab = False
using_Anaconda_on_Mac_or_Linux = True
using_Anaconda_on_windows = False

if using_Google_colab:
    dir_input = "/content/drive/MyDrive/COVID_Project/input"
    dir_output = "/content/drive/MyDrive/COVID_Project/output"
if using_Anaconda_on_Mac_or_Linux:
    dir_input = "../input"
    dir_output = "../output"    
if using_Anaconda_on_windows:
    dir_input = r"..\input"  
    dir_output = r"..\output"

# %%
if using_Google_colab:
    from google.colab import drive
    drive.mount('/content/drive')

# %% [markdown]
# ## DM1.1 Open Notebook titled “Step-4-Develop-Model-Task-1-Prediction-setup” and upload the state data, organizing by date while replacing empty cells with zeros - Activities 1 and 2

# %% [markdown]
# ### Upload State level Data

# %%
df_abt_by_state = pd.read_csv(os.path.join(dir_output, 'abt_by_state.csv'),
                              index_col=['Date'], 
                              parse_dates=['Date'])
df_abt_by_state
# Out:
#             Unnamed: 0  Unnamed: 0.1 State  stateFIPS  Total Cases  \
# Date
# 2020-01-22           0             1    AL          1            0
# 2020-01-23           1            52    AL          1            0
# 2020-01-24           2           103    AL          1            0
# 2020-01-25           3           154    AL          1            0
# 2020-01-26           4           205    AL          1            0
# ...                ...           ...   ...        ...          ...
# 2020-12-16       17029         16785    CT          9       157781
# 2020-12-17       17030         16836    CT          9       160102
# 2020-12-18       17031         16887    CT          9       162782
# 2020-12-19       17032         16938    CT          9       162782
# 2020-12-20       17033         16989    CT          9       162782
#
#             Incremental Cases  cases moving_avg  Total Deaths  \
# Date
# 2020-01-22                NaN               NaN             0
# 2020-01-23                0.0               NaN             0
# 2020-01-24                0.0               NaN             0
# 2020-01-25                0.0               NaN             0
# 2020-01-26                0.0               NaN             0
# ...                       ...               ...           ...
# 2020-12-16             2319.0       2461.857143          5506
# 2020-12-17             2321.0       2446.142857          5552
# 2020-12-18             2680.0       2288.714286          5581
# 2020-12-19                0.0       2288.714286          5581
# 2020-12-20                0.0       2288.714286          5581
#
#             Incremental Deaths  death moving_avg
# Date
# 2020-01-22                 NaN               NaN
# 2020-01-23                 0.0               NaN
# 2020-01-24                 0.0               NaN
# 2020-01-25                 0.0               NaN
# 2020-01-26                 0.0               NaN
# ...                        ...               ...
# 2020-12-16                40.0         31.571429
# 2020-12-17                46.0         32.142857
# 2020-12-18                29.0         31.142857
# 2020-12-19                 0.0         31.142857
# 2020-12-20                 0.0         31.142857
#
# [17034 rows x 10 columns]

# %% [markdown]
# ### Filter Data to a specific state (e.g., NJ)

# %%
df_abt_chosen_state = df_abt_by_state[df_abt_by_state['State'] == 'NJ']
df_abt_chosen_state = df_abt_chosen_state.dropna()
df_abt_chosen_state
# Out:
#             Unnamed: 0  Unnamed: 0.1 State  stateFIPS  Total Cases  \
# Date
# 2020-01-29        8357           388    NJ         34            0
# 2020-01-30        8358           439    NJ         34            0
# 2020-01-31        8359           490    NJ         34            0
# 2020-02-01        8360           541    NJ         34            0
# 2020-02-02        8361           592    NJ         34            0
# ...                ...           ...   ...        ...          ...
# 2020-12-16        8679         16810    NJ         34       415075
# 2020-12-17        8680         16861    NJ         34       419330
# 2020-12-18        8681         16912    NJ         34       423226
# 2020-12-19        8682         16963    NJ         34       427417
# 2020-12-20        8683         17014    NJ         34       432592
#
#             Incremental Cases  cases moving_avg  Total Deaths  \
# Date
# 2020-01-29                0.0          0.000000             0
# 2020-01-30                0.0          0.000000             0
# 2020-01-31                0.0          0.000000             0
# 2020-02-01                0.0          0.000000             0
# 2020-02-02                0.0          0.000000             0
# ...                       ...               ...           ...
# 2020-12-16             5661.0       4798.428571         18003
# 2020-12-17             4255.0       4674.857143         18080
# 2020-12-18             3896.0       4710.000000         18124
# 2020-12-19             4191.0       4417.285714         18173
# 2020-12-20             5175.0       4563.142857         18194
#
#             Incremental Deaths  death moving_avg
# Date
# 2020-01-29                 0.0          0.000000
# 2020-01-30                 0.0          0.000000
# 2020-01-31                 0.0          0.000000
# 2020-02-01                 0.0          0.000000
# 2020-02-02                 0.0          0.000000
# ...                        ...               ...
# 2020-12-16               131.0         65.857143
# 2020-12-17                77.0         67.428571
# 2020-12-18                44.0         66.000000
# 2020-12-19                49.0         63.142857
# 2020-12-20                21.0         63.285714
#
# [327 rows x 10 columns]

# %% [markdown]
# ### DM 1.2 -  Activity 3: Select incremental cases and incremental deaths columns respectively as series, find their max and normalize.

# %%
state_covid_cases = df_abt_chosen_state['Incremental Cases']
cases_max = state_covid_cases.max()
state_covid_cases = state_covid_cases/cases_max
state_covid_deaths = df_abt_chosen_state['Incremental Deaths']
deaths_max = state_covid_deaths.max()
state_covid_deaths = state_covid_deaths / deaths_max

# %% [markdown]
# ### DM1.3 - Visualize the data and make observations
# ### Activity 4 - Plot Incremental Cases and Incremental Deaths

# %%
plt.figure(figsize=(17,8))
plt.title('Comparing cases and deaths over time')
plt.ylabel('Incremental Cases and Deaths')
plt.xlabel('day')
plt.plot(state_covid_cases, 'b', label='incremental cases')
plt.plot(state_covid_deaths, 'r', label='incremental deaths')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ### DM1.4  - Activity 5 - Compute 7 days and 30 days moving averages and visualize cross over points

# %%
state_covid_cases_ewm_7 = state_covid_cases.ewm(span=7, adjust= False).mean()
state_covid_deaths_ewm_7 = state_covid_deaths.ewm(span=7, adjust=False).mean()
state_covid_cases_ewm_30 = state_covid_cases.ewm(span=30, adjust= False).mean()
state_covid_deaths_ewm_30 = state_covid_deaths.ewm(span=30, adjust=False).mean()

# %% [markdown]
# ### DM1.4 - Activity 5 - Plot 30 days average

# %%
plt.figure(figsize=(17,8))
plt.title('Comparing cases and deaths using 30 days rolling means')
plt.ylabel('Incremental Cases and Deaths')
plt.xlabel('day')
plt.plot(state_covid_cases_ewm_30, 'b', label='30 days rolling mean incremental cases')
plt.plot(state_covid_deaths_ewm_30, 'r', label='30 days rolling mean incremental deaths')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### DM1.4 - Activity 6 - Compare 7 days and 30 days averages to identify cross over points

# %%
plt.figure(figsize=(17,8))
plt.title('Comparing cases with 7 days and 30 days rolling means')
plt.ylabel('Incremental Cases')
plt.xlabel('day')
#plt.plot(normalized_state_covid_cases, 'b', label='incremental cases')
plt.plot(state_covid_cases_ewm_7, 'r', label='7 days rolling mean incremental cases')
plt.plot(state_covid_cases_ewm_30, 'c', label='30 days rolling mean incremental cases')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Activity 6: Compute delta between 7 days and 30 days - Compute MACD

# %%
delta_cases = state_covid_cases_ewm_7 - state_covid_cases_ewm_30

# %%
plt.figure(figsize=(17,8))
plt.title('Plot MACD (Moving Average Convergence / Divergence')
plt.ylabel('MACD cases')
plt.xlabel('day')
plt.plot(delta_cases, 'r', label='Delta Cases')
plt.legend(loc='best')
plt.grid(True)
plt.show()
