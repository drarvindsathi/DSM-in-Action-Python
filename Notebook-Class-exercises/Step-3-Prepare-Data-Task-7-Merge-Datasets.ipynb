# %% [markdown]
# # Step 3 - Prepare Data - Task 7 - Merge Dataset

# %% [markdown]
# ## Import libraries

# %%
import os
import pandas as pd
from datetime import date

# %% [markdown]
# ## Set up environment flag

# %%
using_Google_colab = False
using_Anaconda_on_Mac_or_Linux = True
using_Anaconda_on_windows = False

if using_Google_colab:
    dir_input = "/content/drive/MyDrive/COVID_Project/input"
    dir_output = "/content/drive/MyDrive/COVID_Project/output"
if using_Anaconda_on_Mac_or_Linux:
    dir_input = "../input"
    dir_output = "../output"    
if using_Anaconda_on_windows:
    dir_input = r"..\input"  
    dir_output = r"..\output"

# %% [markdown]
# ## If using Google colab, get connected to google drive

# %%
if using_Google_colab:
    from google.colab import drive
    drive.mount('/content/drive')

# %% [markdown]
# ## PD 7.1 Activity 1 - Upload county level covid cases data by county

# %%
df_sorted_confirmed_cases_county = pd.read_csv(os.path.join(dir_output, 'confirmed_cases_by_county.csv'))
df_sorted_confirmed_cases_county = df_sorted_confirmed_cases_county.astype({'countyFIPS': int, 
                                                                            'StateFIPS': int,
                                                                            'Date': 'datetime64[ns]'})
df_sorted_confirmed_cases_county
# Out:
#          Unnamed: 0 State  StateFIPS            County Name  countyFIPS  \
# 0                 0    AL          1  Statewide Unallocated           0
# 1              3193    AL          1  Statewide Unallocated           0
# 2              6386    AL          1  Statewide Unallocated           0
# 3              9579    AL          1  Statewide Unallocated           0
# 4             12772    AL          1  Statewide Unallocated           0
# ...             ...   ...        ...                    ...         ...
# 2353236     2337598    CT          9        Windham County         9015
# 2353237     2340791    CT          9        Windham County         9015
# 2353238     2343984    CT          9        Windham County         9015
# 2353239     2347177    CT          9        Windham County         9015
# 2353240     2350370    CT          9        Windham County         9015
#
#               Date  Total Cases  Incremental Cases  cases moving_avg
# 0       2020-01-22            0                NaN               NaN
# 1       2020-01-23            0                0.0               NaN
# 2       2020-01-24            0                0.0               NaN
# 3       2020-01-25            0                0.0               NaN
# 4       2020-01-26            0                0.0               NaN
# ...            ...          ...                ...               ...
# 2353236 2022-01-23        23067                0.0        201.428571
# 2353237 2022-01-24        23620              553.0        178.000000
# 2353238 2022-01-25        23811              191.0        186.714286
# 2353239 2022-01-26        23984              173.0        184.571429
# 2353240 2022-01-27        24151              167.0        192.285714
#
# [2353241 rows x 9 columns]

# %% [markdown]
# ## PD 7.1 Activity 2 - Upload county level covid deaths by county

# %%
df_sorted_covid_deaths_county = pd.read_csv(os.path.join(dir_output, 'covid_deaths_by_county.csv'))
df_sorted_covid_deaths_county = df_sorted_covid_deaths_county.astype({'countyFIPS': int, 
                                                                            'StateFIPS': int,
                                                                            'Date': 'datetime64[ns]'})
df_sorted_covid_deaths_county
# Out:
#          Unnamed: 0 State  StateFIPS            County Name  countyFIPS  \
# 0                 0    AL          1  Statewide Unallocated           0
# 1                68    AK          2  Statewide Unallocated           0
# 2                98    AZ          4  Statewide Unallocated           0
# 3               114    AR          5  Statewide Unallocated           0
# 4               190    CA          6  Statewide Unallocated           0
# ...             ...   ...        ...                    ...         ...
# 2353236     2337598    CT          9        Windham County         9015
# 2353237     2340791    CT          9        Windham County         9015
# 2353238     2343984    CT          9        Windham County         9015
# 2353239     2347177    CT          9        Windham County         9015
# 2353240     2350370    CT          9        Windham County         9015
#
#               Date  Total Deaths  Inc Deaths  death moving_avg
# 0       2020-01-22             0         NaN               NaN
# 1       2020-01-22             0         0.0               NaN
# 2       2020-01-22             0         0.0               NaN
# 3       2020-01-22             0         0.0               NaN
# 4       2020-01-22             0         0.0               NaN
# ...            ...           ...         ...               ...
# 2353236 2022-01-23           265         0.0          1.000000
# 2353237 2022-01-24           267         2.0          1.285714
# 2353238 2022-01-25           268         1.0          1.428571
# 2353239 2022-01-26           272         4.0          1.714286
# 2353240 2022-01-27           272         0.0          1.714286
#
# [2353241 rows x 9 columns]

# %% [markdown]
# ## PD 7.2 Activity 3 - Merge covid cases and deaths data for each county and date

# %%
df_partial_abt_by_county = pd.merge(df_sorted_confirmed_cases_county, df_sorted_covid_deaths_county, 
                                    on=['StateFIPS','countyFIPS', 'Date'], 
                                    suffixes=('', '_DROP'), 
                                    how='inner').filter(regex='^(?!.*_DROP)')
df_partial_abt_by_county
# Out:
#          Unnamed: 0 State  StateFIPS            County Name  countyFIPS  \
# 0                 0    AL          1  Statewide Unallocated           0
# 1              3193    AL          1  Statewide Unallocated           0
# 2              6386    AL          1  Statewide Unallocated           0
# 3              9579    AL          1  Statewide Unallocated           0
# 4             12772    AL          1  Statewide Unallocated           0
# ...             ...   ...        ...                    ...         ...
# 2353236     2337598    CT          9        Windham County         9015
# 2353237     2340791    CT          9        Windham County         9015
# 2353238     2343984    CT          9        Windham County         9015
# 2353239     2347177    CT          9        Windham County         9015
# 2353240     2350370    CT          9        Windham County         9015
#
#               Date  Total Cases  Incremental Cases  cases moving_avg  \
# 0       2020-01-22            0                NaN               NaN
# 1       2020-01-23            0                0.0               NaN
# 2       2020-01-24            0                0.0               NaN
# 3       2020-01-25            0                0.0               NaN
# 4       2020-01-26            0                0.0               NaN
# ...            ...          ...                ...               ...
# 2353236 2022-01-23        23067                0.0        201.428571
# 2353237 2022-01-24        23620              553.0        178.000000
# 2353238 2022-01-25        23811              191.0        186.714286
# 2353239 2022-01-26        23984              173.0        184.571429
# 2353240 2022-01-27        24151              167.0        192.285714
#
#          Total Deaths  Inc Deaths  death moving_avg
# 0                   0         NaN               NaN
# 1                   0         0.0          0.000000
# 2                   0         0.0          0.000000
# 3                   0         0.0          0.000000
# 4                   0         0.0          0.000000
# ...               ...         ...               ...
# 2353236           265         0.0          1.000000
# 2353237           267         2.0          1.285714
# 2353238           268         1.0          1.428571
# 2353239           272         4.0          1.714286
# 2353240           272         0.0          1.714286
#
# [2353241 rows x 12 columns]

# %% [markdown]
# ## PD 7.3 Activity 4 - Upload county level Google social mobility data

# %%
df_google_mobility_data = pd.read_csv(os.path.join(dir_input, 'Google', 'Region_Mobility_Report_CSVs', '2020_US_Region_Mobility_Report.csv'))
df_google_mobility_data = df_google_mobility_data.astype({'date': 'datetime64[ns]'})
df_google_mobility_data
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 0                       US  United States          NaN            NaN
# 1                       US  United States          NaN            NaN
# 2                       US  United States          NaN            NaN
# 3                       US  United States          NaN            NaN
# 4                       US  United States          NaN            NaN
# ...                    ...            ...          ...            ...
# 812060                  US  United States      Wyoming  Weston County
# 812061                  US  United States      Wyoming  Weston County
# 812062                  US  United States      Wyoming  Weston County
# 812063                  US  United States      Wyoming  Weston County
# 812064                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 0              NaN             NaN               NaN
# 1              NaN             NaN               NaN
# 2              NaN             NaN               NaN
# 3              NaN             NaN               NaN
# 4              NaN             NaN               NaN
# ...            ...             ...               ...
# 812060         NaN             NaN           56045.0
# 812061         NaN             NaN           56045.0
# 812062         NaN             NaN           56045.0
# 812063         NaN             NaN           56045.0
# 812064         NaN             NaN           56045.0
#
#                            place_id       date  \
# 0       ChIJCzYy5IS16lQRQrfeQ5K5Oxw 2020-02-15
# 1       ChIJCzYy5IS16lQRQrfeQ5K5Oxw 2020-02-16
# 2       ChIJCzYy5IS16lQRQrfeQ5K5Oxw 2020-02-17
# 3       ChIJCzYy5IS16lQRQrfeQ5K5Oxw 2020-02-18
# 4       ChIJCzYy5IS16lQRQrfeQ5K5Oxw 2020-02-19
# ...                             ...        ...
# 812060  ChIJd4Rqhed3YocR7ubT5-HgoJg 2020-12-24
# 812061  ChIJd4Rqhed3YocR7ubT5-HgoJg 2020-12-28
# 812062  ChIJd4Rqhed3YocR7ubT5-HgoJg 2020-12-29
# 812063  ChIJd4Rqhed3YocR7ubT5-HgoJg 2020-12-30
# 812064  ChIJd4Rqhed3YocR7ubT5-HgoJg 2020-12-31
#
#         retail_and_recreation_percent_change_from_baseline  \
# 0                                                     6.0
# 1                                                     7.0
# 2                                                     6.0
# 3                                                     0.0
# 4                                                     2.0
# ...                                                   ...
# 812060                                                NaN
# 812061                                                NaN
# 812062                                                NaN
# 812063                                                NaN
# 812064                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     2.0
# 1                                                     1.0
# 2                                                     0.0
# 3                                                    -1.0
# 4                                                     0.0
# ...                                                   ...
# 812060                                                NaN
# 812061                                                NaN
# 812062                                                NaN
# 812063                                                NaN
# 812064                                                NaN
#
#         parks_percent_change_from_baseline  \
# 0                                     15.0
# 1                                     16.0
# 2                                     28.0
# 3                                      6.0
# 4                                      8.0
# ...                                    ...
# 812060                                 NaN
# 812061                                 NaN
# 812062                                 NaN
# 812063                                 NaN
# 812064                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                 3.0
# 1                                                 2.0
# 2                                                -9.0
# 3                                                 1.0
# 4                                                 1.0
# ...                                               ...
# 812060                                            NaN
# 812061                                            NaN
# 812062                                            NaN
# 812063                                            NaN
# 812064                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 0                                           2.0
# 1                                           0.0
# 2                                         -24.0
# 3                                           0.0
# 4                                           1.0
# ...                                         ...
# 812060                                    -56.0
# 812061                                    -40.0
# 812062                                    -43.0
# 812063                                    -40.0
# 812064                                    -38.0
#
#         residential_percent_change_from_baseline
# 0                                           -1.0
# 1                                           -1.0
# 2                                            5.0
# 3                                            1.0
# 4                                            0.0
# ...                                          ...
# 812060                                       NaN
# 812061                                       NaN
# 812062                                       NaN
# 812063                                       NaN
# 812064                                       NaN
#
# [812065 rows x 15 columns]

# %% [markdown]
# ## PD 7.3 Activity 5 - Understand Google Mobility data

# %%
df_google_mobility_data.columns
# Out:
# Index(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
#        'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %%
df_partial_abt_by_county[df_partial_abt_by_county['County Name'] == 'Los Angeles County '].count()
# Out:
# Unnamed: 0           737
# State                737
# StateFIPS            737
# County Name          737
# countyFIPS           737
# Date                 737
# Total Cases          737
# Incremental Cases    736
# cases moving_avg     730
# Total Deaths         737
# Inc Deaths           736
# death moving_avg     730
# dtype: int64

# %%
df_google_mobility_data[df_google_mobility_data['sub_region_2'] == 'Los Angeles County'].count()
# Out:
# country_region_code                                   321
# country_region                                        321
# sub_region_1                                          321
# sub_region_2                                          321
# metro_area                                              0
# iso_3166_2_code                                         0
# census_fips_code                                      321
# place_id                                              321
# date                                                  321
# retail_and_recreation_percent_change_from_baseline    321
# grocery_and_pharmacy_percent_change_from_baseline     321
# parks_percent_change_from_baseline                    321
# transit_stations_percent_change_from_baseline         321
# workplaces_percent_change_from_baseline               321
# residential_percent_change_from_baseline              321
# dtype: int64

# %%
df_google_mobility_data[df_google_mobility_data['sub_region_2'] == 'Los Angeles County'].date.min()
# Out:
# Timestamp('2020-02-15 00:00:00')

# %%
df_google_mobility_data[df_google_mobility_data['sub_region_2'] == 'Los Angeles County'].date.max()
# Out:
# Timestamp('2020-12-31 00:00:00')

# %%
df_partial_abt_by_county[df_partial_abt_by_county['County Name'] == 'Los Angeles County '].Date.min()
# Out:
# Timestamp('2020-01-22 00:00:00')

# %%
df_partial_abt_by_county[df_partial_abt_by_county['County Name'] == 'Los Angeles County '].Date.max()
# Out:
# Timestamp('2022-01-27 00:00:00')

# %% [markdown]
# ## PD 7.3 Activity 6: Reformat Google Mobility data

# %%
df_google_mobility_data_clean = df_google_mobility_data.dropna(subset=['census_fips_code'])
df_google_mobility_data_clean = df_google_mobility_data_clean.astype({'census_fips_code': int})
df_google_mobility_data_clean
# Out:
#        country_region_code country_region sub_region_1    sub_region_2  \
# 642                     US  United States      Alabama  Autauga County
# 643                     US  United States      Alabama  Autauga County
# 644                     US  United States      Alabama  Autauga County
# 645                     US  United States      Alabama  Autauga County
# 646                     US  United States      Alabama  Autauga County
# ...                    ...            ...          ...             ...
# 812060                  US  United States      Wyoming   Weston County
# 812061                  US  United States      Wyoming   Weston County
# 812062                  US  United States      Wyoming   Weston County
# 812063                  US  United States      Wyoming   Weston County
# 812064                  US  United States      Wyoming   Weston County
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 642            NaN             NaN              1001
# 643            NaN             NaN              1001
# 644            NaN             NaN              1001
# 645            NaN             NaN              1001
# 646            NaN             NaN              1001
# ...            ...             ...               ...
# 812060         NaN             NaN             56045
# 812061         NaN             NaN             56045
# 812062         NaN             NaN             56045
# 812063         NaN             NaN             56045
# 812064         NaN             NaN             56045
#
#                            place_id       date  \
# 642     ChIJg9z7ewWPjogRA_8QrB0va7o 2020-02-15
# 643     ChIJg9z7ewWPjogRA_8QrB0va7o 2020-02-16
# 644     ChIJg9z7ewWPjogRA_8QrB0va7o 2020-02-17
# 645     ChIJg9z7ewWPjogRA_8QrB0va7o 2020-02-18
# 646     ChIJg9z7ewWPjogRA_8QrB0va7o 2020-02-19
# ...                             ...        ...
# 812060  ChIJd4Rqhed3YocR7ubT5-HgoJg 2020-12-24
# 812061  ChIJd4Rqhed3YocR7ubT5-HgoJg 2020-12-28
# 812062  ChIJd4Rqhed3YocR7ubT5-HgoJg 2020-12-29
# 812063  ChIJd4Rqhed3YocR7ubT5-HgoJg 2020-12-30
# 812064  ChIJd4Rqhed3YocR7ubT5-HgoJg 2020-12-31
#
#         retail_and_recreation_percent_change_from_baseline  \
# 642                                                   5.0
# 643                                                   0.0
# 644                                                   8.0
# 645                                                  -2.0
# 646                                                  -2.0
# ...                                                   ...
# 812060                                                NaN
# 812061                                                NaN
# 812062                                                NaN
# 812063                                                NaN
# 812064                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 642                                                   7.0
# 643                                                   1.0
# 644                                                   0.0
# 645                                                   0.0
# 646                                                   0.0
# ...                                                   ...
# 812060                                                NaN
# 812061                                                NaN
# 812062                                                NaN
# 812063                                                NaN
# 812064                                                NaN
#
#         parks_percent_change_from_baseline  \
# 642                                    NaN
# 643                                  -23.0
# 644                                    NaN
# 645                                    NaN
# 646                                    NaN
# ...                                    ...
# 812060                                 NaN
# 812061                                 NaN
# 812062                                 NaN
# 812063                                 NaN
# 812064                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 642                                               NaN
# 643                                               NaN
# 644                                               NaN
# 645                                               NaN
# 646                                               NaN
# ...                                               ...
# 812060                                            NaN
# 812061                                            NaN
# 812062                                            NaN
# 812063                                            NaN
# 812064                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 642                                        -4.0
# 643                                        -4.0
# 644                                       -27.0
# 645                                         2.0
# 646                                         2.0
# ...                                         ...
# 812060                                    -56.0
# 812061                                    -40.0
# 812062                                    -43.0
# 812063                                    -40.0
# 812064                                    -38.0
#
#         residential_percent_change_from_baseline
# 642                                          NaN
# 643                                          NaN
# 644                                          5.0
# 645                                          0.0
# 646                                          0.0
# ...                                          ...
# 812060                                       NaN
# 812061                                       NaN
# 812062                                       NaN
# 812063                                       NaN
# 812064                                       NaN
#
# [782235 rows x 15 columns]

# %% [markdown]
# ## PD 7.4 Activity 7 - Merge Covid Cases, deaths and Google Data

# %%
df_abt_by_county = pd.merge(df_partial_abt_by_county, 
                            df_google_mobility_data, left_on=['countyFIPS', 'Date'], 
                            right_on=['census_fips_code', 'date'], 
                            suffixes=('', '_DROP'), 
                            how='left').filter(regex='^(?!.*_DROP)')
df_abt_by_county
# Out:
#          Unnamed: 0 State  StateFIPS            County Name  countyFIPS  \
# 0                 0    AL          1  Statewide Unallocated           0
# 1              3193    AL          1  Statewide Unallocated           0
# 2              6386    AL          1  Statewide Unallocated           0
# 3              9579    AL          1  Statewide Unallocated           0
# 4             12772    AL          1  Statewide Unallocated           0
# ...             ...   ...        ...                    ...         ...
# 2353236     2337598    CT          9        Windham County         9015
# 2353237     2340791    CT          9        Windham County         9015
# 2353238     2343984    CT          9        Windham County         9015
# 2353239     2347177    CT          9        Windham County         9015
# 2353240     2350370    CT          9        Windham County         9015
#
#               Date  Total Cases  Incremental Cases  cases moving_avg  \
# 0       2020-01-22            0                NaN               NaN
# 1       2020-01-23            0                0.0               NaN
# 2       2020-01-24            0                0.0               NaN
# 3       2020-01-25            0                0.0               NaN
# 4       2020-01-26            0                0.0               NaN
# ...            ...          ...                ...               ...
# 2353236 2022-01-23        23067                0.0        201.428571
# 2353237 2022-01-24        23620              553.0        178.000000
# 2353238 2022-01-25        23811              191.0        186.714286
# 2353239 2022-01-26        23984              173.0        184.571429
# 2353240 2022-01-27        24151              167.0        192.285714
#
#          Total Deaths  ...  iso_3166_2_code  census_fips_code place_id date  \
# 0                   0  ...              NaN               NaN      NaN  NaT
# 1                   0  ...              NaN               NaN      NaN  NaT
# 2                   0  ...              NaN               NaN      NaN  NaT
# 3                   0  ...              NaN               NaN      NaN  NaT
# 4                   0  ...              NaN               NaN      NaN  NaT
# ...               ...  ...              ...               ...      ...  ...
# 2353236           265  ...              NaN               NaN      NaN  NaT
# 2353237           267  ...              NaN               NaN      NaN  NaT
# 2353238           268  ...              NaN               NaN      NaN  NaT
# 2353239           272  ...              NaN               NaN      NaN  NaT
# 2353240           272  ...              NaN               NaN      NaN  NaT
#
#         retail_and_recreation_percent_change_from_baseline  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 2353236                                                NaN
# 2353237                                                NaN
# 2353238                                                NaN
# 2353239                                                NaN
# 2353240                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 2353236                                               NaN
# 2353237                                               NaN
# 2353238                                               NaN
# 2353239                                               NaN
# 2353240                                               NaN
#
#          parks_percent_change_from_baseline  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 2353236                                 NaN
# 2353237                                 NaN
# 2353238                                 NaN
# 2353239                                 NaN
# 2353240                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 2353236                                           NaN
# 2353237                                           NaN
# 2353238                                           NaN
# 2353239                                           NaN
# 2353240                                           NaN
#
#          workplaces_percent_change_from_baseline  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 2353236                                      NaN
# 2353237                                      NaN
# 2353238                                      NaN
# 2353239                                      NaN
# 2353240                                      NaN
#
#         residential_percent_change_from_baseline
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 2353236                                      NaN
# 2353237                                      NaN
# 2353238                                      NaN
# 2353239                                      NaN
# 2353240                                      NaN
#
# [2353241 rows x 27 columns]

# %% [markdown]
# ## PD7.4 Activity 8: Save County Data as Analytics Base Table

# %%
df_abt_by_county.to_csv(os.path.join(dir_output, 'abt_by_county.csv'))

# %%
df_abt_LA_county = df_abt_by_county[df_abt_by_county['County Name'] == 'Los Angeles County ']
df_abt_LA_county
# Out:
#          Unnamed: 0 State  StateFIPS          County Name  countyFIPS  \
# 2269223         209    CA          6  Los Angeles County         6037
# 2269224        3402    CA          6  Los Angeles County         6037
# 2269225        6595    CA          6  Los Angeles County         6037
# 2269226        9788    CA          6  Los Angeles County         6037
# 2269227       12981    CA          6  Los Angeles County         6037
# ...             ...   ...        ...                  ...         ...
# 2269955     2337485    CA          6  Los Angeles County         6037
# 2269956     2340678    CA          6  Los Angeles County         6037
# 2269957     2343871    CA          6  Los Angeles County         6037
# 2269958     2347064    CA          6  Los Angeles County         6037
# 2269959     2350257    CA          6  Los Angeles County         6037
#
#               Date  Total Cases  Incremental Cases  cases moving_avg  \
# 2269223 2020-01-22          375                NaN               NaN
# 2269224 2020-01-23          379                4.0               NaN
# 2269225 2020-01-24          382                3.0               NaN
# 2269226 2020-01-25          384                2.0               NaN
# 2269227 2020-01-26          385                1.0               NaN
# ...            ...          ...                ...               ...
# 2269955 2022-01-23      2430653            40171.0      26989.142857
# 2269956 2022-01-24      2453693            23040.0      26929.285714
# 2269957 2022-01-25      2468026            14333.0      27376.857143
# 2269958 2022-01-26      2472960             4934.0      18528.428571
# 2269959 2022-01-27      2473095              135.0      15099.142857
#
#          Total Deaths  ...  iso_3166_2_code  census_fips_code place_id date  \
# 2269223             0  ...              NaN               NaN      NaN  NaT
# 2269224             0  ...              NaN               NaN      NaN  NaT
# 2269225             0  ...              NaN               NaN      NaN  NaT
# 2269226             0  ...              NaN               NaN      NaN  NaT
# 2269227             0  ...              NaN               NaN      NaN  NaT
# ...               ...  ...              ...               ...      ...  ...
# 2269955         28276  ...              NaN               NaN      NaN  NaT
# 2269956         28433  ...              NaN               NaN      NaN  NaT
# 2269957         28458  ...              NaN               NaN      NaN  NaT
# 2269958         28463  ...              NaN               NaN      NaN  NaT
# 2269959         28463  ...              NaN               NaN      NaN  NaT
#
#         retail_and_recreation_percent_change_from_baseline  \
# 2269223                                                NaN
# 2269224                                                NaN
# 2269225                                                NaN
# 2269226                                                NaN
# 2269227                                                NaN
# ...                                                    ...
# 2269955                                                NaN
# 2269956                                                NaN
# 2269957                                                NaN
# 2269958                                                NaN
# 2269959                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 2269223                                               NaN
# 2269224                                               NaN
# 2269225                                               NaN
# 2269226                                               NaN
# 2269227                                               NaN
# ...                                                   ...
# 2269955                                               NaN
# 2269956                                               NaN
# 2269957                                               NaN
# 2269958                                               NaN
# 2269959                                               NaN
#
#          parks_percent_change_from_baseline  \
# 2269223                                 NaN
# 2269224                                 NaN
# 2269225                                 NaN
# 2269226                                 NaN
# 2269227                                 NaN
# ...                                     ...
# 2269955                                 NaN
# 2269956                                 NaN
# 2269957                                 NaN
# 2269958                                 NaN
# 2269959                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 2269223                                           NaN
# 2269224                                           NaN
# 2269225                                           NaN
# 2269226                                           NaN
# 2269227                                           NaN
# ...                                               ...
# 2269955                                           NaN
# 2269956                                           NaN
# 2269957                                           NaN
# 2269958                                           NaN
# 2269959                                           NaN
#
#          workplaces_percent_change_from_baseline  \
# 2269223                                      NaN
# 2269224                                      NaN
# 2269225                                      NaN
# 2269226                                      NaN
# 2269227                                      NaN
# ...                                          ...
# 2269955                                      NaN
# 2269956                                      NaN
# 2269957                                      NaN
# 2269958                                      NaN
# 2269959                                      NaN
#
#         residential_percent_change_from_baseline
# 2269223                                      NaN
# 2269224                                      NaN
# 2269225                                      NaN
# 2269226                                      NaN
# 2269227                                      NaN
# ...                                          ...
# 2269955                                      NaN
# 2269956                                      NaN
# 2269957                                      NaN
# 2269958                                      NaN
# 2269959                                      NaN
#
# [737 rows x 27 columns]

# %%
df_abt_LA_county.to_csv(os.path.join(dir_output, 'abt_LA_county.csv'))

# %%
df_abt_Orange_county_CA = df_abt_by_county[df_abt_by_county['countyFIPS'] == 6059]
df_abt_Orange_county_CA
# Out:
#          Unnamed: 0 State  StateFIPS     County Name  countyFIPS       Date  \
# 2277330         220    CA          6  Orange County         6059 2020-01-22
# 2277331        3413    CA          6  Orange County         6059 2020-01-23
# 2277332        6606    CA          6  Orange County         6059 2020-01-24
# 2277333        9799    CA          6  Orange County         6059 2020-01-25
# 2277334       12992    CA          6  Orange County         6059 2020-01-26
# ...             ...   ...        ...             ...         ...        ...
# 2278062     2337496    CA          6  Orange County         6059 2022-01-23
# 2278063     2340689    CA          6  Orange County         6059 2022-01-24
# 2278064     2343882    CA          6  Orange County         6059 2022-01-25
# 2278065     2347075    CA          6  Orange County         6059 2022-01-26
# 2278066     2350268    CA          6  Orange County         6059 2022-01-27
#
#          Total Cases  Incremental Cases  cases moving_avg  Total Deaths  ...  \
# 2277330            8                NaN               NaN             0  ...
# 2277331            8                0.0               NaN             0  ...
# 2277332            9                1.0               NaN             0  ...
# 2277333            9                0.0               NaN             0  ...
# 2277334            9                0.0               NaN             0  ...
# ...              ...                ...               ...           ...  ...
# 2278062       503296             2883.0       5496.285714          5978  ...
# 2278063       507671             4375.0       4701.142857          6035  ...
# 2278064       509881             2210.0       4562.714286          6035  ...
# 2278065       510999             1118.0       3245.000000          6035  ...
# 2278066       511260              261.0       2578.142857          6035  ...
#
#          iso_3166_2_code  census_fips_code place_id date  \
# 2277330              NaN               NaN      NaN  NaT
# 2277331              NaN               NaN      NaN  NaT
# 2277332              NaN               NaN      NaN  NaT
# 2277333              NaN               NaN      NaN  NaT
# 2277334              NaN               NaN      NaN  NaT
# ...                  ...               ...      ...  ...
# 2278062              NaN               NaN      NaN  NaT
# 2278063              NaN               NaN      NaN  NaT
# 2278064              NaN               NaN      NaN  NaT
# 2278065              NaN               NaN      NaN  NaT
# 2278066              NaN               NaN      NaN  NaT
#
#         retail_and_recreation_percent_change_from_baseline  \
# 2277330                                                NaN
# 2277331                                                NaN
# 2277332                                                NaN
# 2277333                                                NaN
# 2277334                                                NaN
# ...                                                    ...
# 2278062                                                NaN
# 2278063                                                NaN
# 2278064                                                NaN
# 2278065                                                NaN
# 2278066                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 2277330                                               NaN
# 2277331                                               NaN
# 2277332                                               NaN
# 2277333                                               NaN
# 2277334                                               NaN
# ...                                                   ...
# 2278062                                               NaN
# 2278063                                               NaN
# 2278064                                               NaN
# 2278065                                               NaN
# 2278066                                               NaN
#
#          parks_percent_change_from_baseline  \
# 2277330                                 NaN
# 2277331                                 NaN
# 2277332                                 NaN
# 2277333                                 NaN
# 2277334                                 NaN
# ...                                     ...
# 2278062                                 NaN
# 2278063                                 NaN
# 2278064                                 NaN
# 2278065                                 NaN
# 2278066                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 2277330                                           NaN
# 2277331                                           NaN
# 2277332                                           NaN
# 2277333                                           NaN
# 2277334                                           NaN
# ...                                               ...
# 2278062                                           NaN
# 2278063                                           NaN
# 2278064                                           NaN
# 2278065                                           NaN
# 2278066                                           NaN
#
#          workplaces_percent_change_from_baseline  \
# 2277330                                      NaN
# 2277331                                      NaN
# 2277332                                      NaN
# 2277333                                      NaN
# 2277334                                      NaN
# ...                                          ...
# 2278062                                      NaN
# 2278063                                      NaN
# 2278064                                      NaN
# 2278065                                      NaN
# 2278066                                      NaN
#
#         residential_percent_change_from_baseline
# 2277330                                      NaN
# 2277331                                      NaN
# 2277332                                      NaN
# 2277333                                      NaN
# 2277334                                      NaN
# ...                                          ...
# 2278062                                      NaN
# 2278063                                      NaN
# 2278064                                      NaN
# 2278065                                      NaN
# 2278066                                      NaN
#
# [737 rows x 27 columns]

# %%
df_abt_Orange_county_CA.to_csv(os.path.join(dir_output, 'abt_Orange_county.csv'))
