# %% [markdown]
# # Step 3 - Prepare Data - Task 7 - Merge Dataset

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
from datetime import date

# %% [markdown]
# ## Set up environment flag

# %%
using_Google_colab = False
using_Anaconda_on_Mac_or_Linux = True
using_Anaconda_on_windows = False

# %% [markdown]
# ## If using Google colab, get connected to google drive

# %%
if using_Google_colab:
    from google.colab import drive
    drive.mount('/content/drive')

# %% [markdown]
# ## PD 7.1 Activity 1 - Upload county level covid cases data by county

# %%
if using_Google_colab:
    df_sorted_confirmed_cases_county = pd.read_csv('/content/drive/MyDrive/COVID_Project/output/confirmed_cases_by_county.csv')
if using_Anaconda_on_Mac_or_Linux:
    df_sorted_confirmed_cases_county = pd.read_csv('../output/confirmed_cases_by_county.csv')
if using_Anaconda_on_windows:
    df_sorted_confirmed_cases_county = pd.read_csv(r'../output/confirmed_cases_by_county.csv') 
df_sorted_confirmed_cases_county = df_sorted_confirmed_cases_county.astype({'countyFIPS': int, 
                                                                            'stateFIPS': int,
                                                                            'Date': 'datetime64[ns]'})
df_sorted_confirmed_cases_county
# Out:
#          Unnamed: 0 State  stateFIPS            County Name  countyFIPS  \
# 0                 0    AL          1  Statewide Unallocated           0
# 1              3195    AL          1  Statewide Unallocated           0
# 2              6390    AL          1  Statewide Unallocated           0
# 3              9585    AL          1  Statewide Unallocated           0
# 4             12780    AL          1  Statewide Unallocated           0
# ...             ...   ...        ...                    ...         ...
# 1067125     1051479    CT          9         Windham County        9015
# 1067126     1054674    CT          9         Windham County        9015
# 1067127     1057869    CT          9         Windham County        9015
# 1067128     1061064    CT          9         Windham County        9015
# 1067129     1064259    CT          9         Windham County        9015
#
#               Date  Total Cases  Incremental Cases  cases moving_avg
# 0       2020-01-22            0                NaN               NaN
# 1       2020-01-23            0                0.0               NaN
# 2       2020-01-24            0                0.0               NaN
# 3       2020-01-25            0                0.0               NaN
# 4       2020-01-26            0                0.0               NaN
# ...            ...          ...                ...               ...
# 1067125 2020-12-16         3921              130.0         90.142857
# 1067126 2020-12-17         3998               77.0         90.285714
# 1067127 2020-12-18         4153              155.0        103.714286
# 1067128 2020-12-19         4153                0.0        103.714286
# 1067129 2020-12-20         4153                0.0        103.714286
#
# [1067130 rows x 9 columns]

# %% [markdown]
# ## PD 7.1 Activity 2 - Upload county level covid deaths by county

# %%
if using_Google_colab:
    df_sorted_covid_deaths_county = pd.read_csv('/content/drive/MyDrive/COVID_Project/output/covid_deaths_by_county.csv')
if using_Anaconda_on_Mac_or_Linux:
    df_sorted_covid_deaths_county = pd.read_csv('../output/covid_deaths_by_county.csv')
if using_Anaconda_on_windows:
    df_sorted_covid_deaths_county = pd.read_csv(r'../output/covid_deaths_by_county.csv') 
df_sorted_covid_deaths_county = df_sorted_covid_deaths_county.astype({'countyFIPS': int, 
                                                                            'stateFIPS': int,
                                                                            'Date': 'datetime64[ns]'})
df_sorted_covid_deaths_county
# Out:
#          Unnamed: 0 State  stateFIPS            County Name  countyFIPS  \
# 0                 0    AL          1  Statewide Unallocated           0
# 1                68    AK          2  Statewide Unallocated           0
# 2                99    AZ          4  Statewide Unallocated           0
# 3               115    AR          5  Statewide Unallocated           0
# 4               191    CA          6  Statewide Unallocated           0
# ...             ...   ...        ...                    ...         ...
# 1067125     1051479    CT          9         Windham County        9015
# 1067126     1054674    CT          9         Windham County        9015
# 1067127     1057869    CT          9         Windham County        9015
# 1067128     1061064    CT          9         Windham County        9015
# 1067129     1064259    CT          9         Windham County        9015
#
#               Date  Total Deaths  Inc Deaths  death moving_avg
# 0       2020-01-22             0         NaN               NaN
# 1       2020-01-22             0         0.0               NaN
# 2       2020-01-22             0         0.0               NaN
# 3       2020-01-22             0         0.0               NaN
# 4       2020-01-22             0         0.0               NaN
# ...            ...           ...         ...               ...
# 1067125 2020-12-16            48         2.0          1.714286
# 1067126 2020-12-17            51         3.0          1.571429
# 1067127 2020-12-18            51         0.0          1.285714
# 1067128 2020-12-19            51         0.0          1.285714
# 1067129 2020-12-20            51         0.0          1.285714
#
# [1067130 rows x 9 columns]

# %% [markdown]
# ## PD 7.2 Activity 3 - Merge covid cases and deaths data for each county and date

# %%
df_partial_abt_by_county = pd.merge(df_sorted_confirmed_cases_county, df_sorted_covid_deaths_county, 
                                    on=['stateFIPS','countyFIPS', 'Date'], 
                                    suffixes=('', '_DROP'), 
                                    how='inner').filter(regex='^(?!.*_DROP)')
df_partial_abt_by_county
# Out:
#          Unnamed: 0 State  stateFIPS            County Name  countyFIPS  \
# 0                 0    AL          1  Statewide Unallocated           0
# 1              3195    AL          1  Statewide Unallocated           0
# 2              6390    AL          1  Statewide Unallocated           0
# 3              9585    AL          1  Statewide Unallocated           0
# 4             12780    AL          1  Statewide Unallocated           0
# ...             ...   ...        ...                    ...         ...
# 1067125     1051479    CT          9         Windham County        9015
# 1067126     1054674    CT          9         Windham County        9015
# 1067127     1057869    CT          9         Windham County        9015
# 1067128     1061064    CT          9         Windham County        9015
# 1067129     1064259    CT          9         Windham County        9015
#
#               Date  Total Cases  Incremental Cases  cases moving_avg  \
# 0       2020-01-22            0                NaN               NaN
# 1       2020-01-23            0                0.0               NaN
# 2       2020-01-24            0                0.0               NaN
# 3       2020-01-25            0                0.0               NaN
# 4       2020-01-26            0                0.0               NaN
# ...            ...          ...                ...               ...
# 1067125 2020-12-16         3921              130.0         90.142857
# 1067126 2020-12-17         3998               77.0         90.285714
# 1067127 2020-12-18         4153              155.0        103.714286
# 1067128 2020-12-19         4153                0.0        103.714286
# 1067129 2020-12-20         4153                0.0        103.714286
#
#          Total Deaths  Inc Deaths  death moving_avg
# 0                   0         NaN               NaN
# 1                   0         0.0          0.000000
# 2                   0         0.0          0.000000
# 3                   0         0.0          0.000000
# 4                   0         0.0          0.000000
# ...               ...         ...               ...
# 1067125            48         2.0          1.714286
# 1067126            51         3.0          1.571429
# 1067127            51         0.0          1.285714
# 1067128            51         0.0          1.285714
# 1067129            51         0.0          1.285714
#
# [1067130 rows x 12 columns]

# %% [markdown]
# ## PD 7.3 Activity 4 - Upload county level Google social mobility data

# %%
if using_Google_colab:
    df_google_mobility_data = pd.read_csv('/content/drive/MyDrive/COVID_Project/input/Google/Region_Mobility_Report_CSVs/2020_US_Region_Mobility_Report.csv')
if using_Anaconda_on_Mac_or_Linux:
    df_google_mobility_data = pd.read_csv('../input/Google/Region_Mobility_Report_CSVs/2020_US_Region_Mobility_Report.csv')
if using_Anaconda_on_windows:
    df_google_mobility_data = pd.read_csv('..\input\Google\Region_Mobility_Report_CSVs\2020_US_Region_Mobility_Report.csv')
df_google_mobility_data = df_google_mobility_data.astype({'date': 'datetime64[ns]'})
df_google_mobility_data
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 0                       US  United States          NaN            NaN
# 1                       US  United States          NaN            NaN
# 2                       US  United States          NaN            NaN
# 3                       US  United States          NaN            NaN
# 4                       US  United States          NaN            NaN
# ...                    ...            ...          ...            ...
# 796331                  US  United States      Wyoming  Weston County
# 796332                  US  United States      Wyoming  Weston County
# 796333                  US  United States      Wyoming  Weston County
# 796334                  US  United States      Wyoming  Weston County
# 796335                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code       date  \
# 0              NaN             NaN               NaN 2020-02-15
# 1              NaN             NaN               NaN 2020-02-16
# 2              NaN             NaN               NaN 2020-02-17
# 3              NaN             NaN               NaN 2020-02-18
# 4              NaN             NaN               NaN 2020-02-19
# ...            ...             ...               ...        ...
# 796331         NaN             NaN           56045.0 2020-12-18
# 796332         NaN             NaN           56045.0 2020-12-21
# 796333         NaN             NaN           56045.0 2020-12-22
# 796334         NaN             NaN           56045.0 2020-12-23
# 796335         NaN             NaN           56045.0 2020-12-24
#
#         retail_and_recreation_percent_change_from_baseline  \
# 0                                                     6.0
# 1                                                     7.0
# 2                                                     6.0
# 3                                                     0.0
# 4                                                     2.0
# ...                                                   ...
# 796331                                                NaN
# 796332                                                NaN
# 796333                                                NaN
# 796334                                                NaN
# 796335                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     2.0
# 1                                                     1.0
# 2                                                     0.0
# 3                                                    -1.0
# 4                                                     0.0
# ...                                                   ...
# 796331                                                NaN
# 796332                                                NaN
# 796333                                                NaN
# 796334                                                NaN
# 796335                                                NaN
#
#         parks_percent_change_from_baseline  \
# 0                                     15.0
# 1                                     16.0
# 2                                     28.0
# 3                                      6.0
# 4                                      8.0
# ...                                    ...
# 796331                                 NaN
# 796332                                 NaN
# 796333                                 NaN
# 796334                                 NaN
# 796335                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                 3.0
# 1                                                 2.0
# 2                                                -9.0
# 3                                                 1.0
# 4                                                 1.0
# ...                                               ...
# 796331                                            NaN
# 796332                                            NaN
# 796333                                            NaN
# 796334                                            NaN
# 796335                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 0                                           2.0
# 1                                           0.0
# 2                                         -24.0
# 3                                           0.0
# 4                                           1.0
# ...                                         ...
# 796331                                    -17.0
# 796332                                    -39.0
# 796333                                    -38.0
# 796334                                    -48.0
# 796335                                    -56.0
#
#         residential_percent_change_from_baseline
# 0                                           -1.0
# 1                                           -1.0
# 2                                            5.0
# 3                                            1.0
# 4                                            0.0
# ...                                          ...
# 796331                                       NaN
# 796332                                       NaN
# 796333                                       NaN
# 796334                                       NaN
# 796335                                       NaN
#
# [796336 rows x 14 columns]

# %% [markdown]
# ## PD 7.3 Activity 5 - Understand Google Mobility data

# %%
df_google_mobility_data.columns
# Out:
# Index(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
#        'metro_area', 'iso_3166_2_code', 'census_fips_code', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %%
df_partial_abt_by_county[df_partial_abt_by_county['County Name'] == 'Los Angeles County'].count()
# Out:
# Unnamed: 0           334
# State                334
# stateFIPS            334
# County Name          334
# countyFIPS           334
# Date                 334
# Total Cases          334
# Incremental Cases    333
# cases moving_avg     327
# Total Deaths         334
# Inc Deaths           333
# death moving_avg     327
# dtype: int64

# %%
df_google_mobility_data[df_google_mobility_data['sub_region_2'] == 'Los Angeles County'].count()
# Out:
# country_region_code                                   315
# country_region                                        315
# sub_region_1                                          315
# sub_region_2                                          315
# metro_area                                              0
# iso_3166_2_code                                         0
# census_fips_code                                      315
# date                                                  315
# retail_and_recreation_percent_change_from_baseline    315
# grocery_and_pharmacy_percent_change_from_baseline     315
# parks_percent_change_from_baseline                    315
# transit_stations_percent_change_from_baseline         315
# workplaces_percent_change_from_baseline               315
# residential_percent_change_from_baseline              315
# dtype: int64

# %%
df_google_mobility_data[df_google_mobility_data['sub_region_2'] == 'Los Angeles County'].date.min()
# Out:
# Timestamp('2020-02-15 00:00:00')

# %%
df_google_mobility_data[df_google_mobility_data['sub_region_2'] == 'Los Angeles County'].date.max()
# Out:
# Timestamp('2020-12-25 00:00:00')

# %%
df_partial_abt_by_county[df_partial_abt_by_county['County Name'] == 'Los Angeles County'].Date.min()
# Out:
# Timestamp('2020-01-22 00:00:00')

# %%
df_partial_abt_by_county[df_partial_abt_by_county['County Name'] == 'Los Angeles County'].Date.max()
# Out:
# Timestamp('2020-12-20 00:00:00')

# %% [markdown]
# ## PD 7.3 Activity 6: Reformat Google Mobility data

# %%
df_google_mobility_data_clean = df_google_mobility_data.dropna(subset=['census_fips_code'])
df_google_mobility_data_clean = df_google_mobility_data_clean.astype({'census_fips_code': int})
df_google_mobility_data_clean
# Out:
#        country_region_code country_region sub_region_1    sub_region_2  \
# 630                     US  United States      Alabama  Autauga County
# 631                     US  United States      Alabama  Autauga County
# 632                     US  United States      Alabama  Autauga County
# 633                     US  United States      Alabama  Autauga County
# 634                     US  United States      Alabama  Autauga County
# ...                    ...            ...          ...             ...
# 796331                  US  United States      Wyoming   Weston County
# 796332                  US  United States      Wyoming   Weston County
# 796333                  US  United States      Wyoming   Weston County
# 796334                  US  United States      Wyoming   Weston County
# 796335                  US  United States      Wyoming   Weston County
#
#         metro_area iso_3166_2_code  census_fips_code       date  \
# 630            NaN             NaN              1001 2020-02-15
# 631            NaN             NaN              1001 2020-02-16
# 632            NaN             NaN              1001 2020-02-17
# 633            NaN             NaN              1001 2020-02-18
# 634            NaN             NaN              1001 2020-02-19
# ...            ...             ...               ...        ...
# 796331         NaN             NaN             56045 2020-12-18
# 796332         NaN             NaN             56045 2020-12-21
# 796333         NaN             NaN             56045 2020-12-22
# 796334         NaN             NaN             56045 2020-12-23
# 796335         NaN             NaN             56045 2020-12-24
#
#         retail_and_recreation_percent_change_from_baseline  \
# 630                                                   5.0
# 631                                                   0.0
# 632                                                   8.0
# 633                                                  -2.0
# 634                                                  -2.0
# ...                                                   ...
# 796331                                                NaN
# 796332                                                NaN
# 796333                                                NaN
# 796334                                                NaN
# 796335                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 630                                                   7.0
# 631                                                   1.0
# 632                                                   0.0
# 633                                                   0.0
# 634                                                   0.0
# ...                                                   ...
# 796331                                                NaN
# 796332                                                NaN
# 796333                                                NaN
# 796334                                                NaN
# 796335                                                NaN
#
#         parks_percent_change_from_baseline  \
# 630                                    NaN
# 631                                  -23.0
# 632                                    NaN
# 633                                    NaN
# 634                                    NaN
# ...                                    ...
# 796331                                 NaN
# 796332                                 NaN
# 796333                                 NaN
# 796334                                 NaN
# 796335                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 630                                               NaN
# 631                                               NaN
# 632                                               NaN
# 633                                               NaN
# 634                                               NaN
# ...                                               ...
# 796331                                            NaN
# 796332                                            NaN
# 796333                                            NaN
# 796334                                            NaN
# 796335                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 630                                        -4.0
# 631                                        -4.0
# 632                                       -27.0
# 633                                         2.0
# 634                                         2.0
# ...                                         ...
# 796331                                    -17.0
# 796332                                    -39.0
# 796333                                    -38.0
# 796334                                    -48.0
# 796335                                    -56.0
#
#         residential_percent_change_from_baseline
# 630                                          NaN
# 631                                          NaN
# 632                                          5.0
# 633                                          0.0
# 634                                          0.0
# ...                                          ...
# 796331                                       NaN
# 796332                                       NaN
# 796333                                       NaN
# 796334                                       NaN
# 796335                                       NaN
#
# [780271 rows x 14 columns]

# %% [markdown]
# ## PD 7.4 Activity 7 - Merge Covid Cases, deaths and Google Data

# %%
df_abt_by_county = pd.merge(df_partial_abt_by_county, 
                            df_google_mobility_data, left_on=['countyFIPS', 'Date'], 
                            right_on=['census_fips_code', 'date'], 
                            suffixes=('', '_DROP'), 
                            how='left').filter(regex='^(?!.*_DROP)')
df_abt_by_county
# Out:
#          Unnamed: 0 State  stateFIPS            County Name  countyFIPS  \
# 0                 0    AL          1  Statewide Unallocated           0
# 1              3195    AL          1  Statewide Unallocated           0
# 2              6390    AL          1  Statewide Unallocated           0
# 3              9585    AL          1  Statewide Unallocated           0
# 4             12780    AL          1  Statewide Unallocated           0
# ...             ...   ...        ...                    ...         ...
# 1067125     1051479    CT          9         Windham County        9015
# 1067126     1054674    CT          9         Windham County        9015
# 1067127     1057869    CT          9         Windham County        9015
# 1067128     1061064    CT          9         Windham County        9015
# 1067129     1064259    CT          9         Windham County        9015
#
#               Date  Total Cases  Incremental Cases  cases moving_avg  \
# 0       2020-01-22            0                NaN               NaN
# 1       2020-01-23            0                0.0               NaN
# 2       2020-01-24            0                0.0               NaN
# 3       2020-01-25            0                0.0               NaN
# 4       2020-01-26            0                0.0               NaN
# ...            ...          ...                ...               ...
# 1067125 2020-12-16         3921              130.0         90.142857
# 1067126 2020-12-17         3998               77.0         90.285714
# 1067127 2020-12-18         4153              155.0        103.714286
# 1067128 2020-12-19         4153                0.0        103.714286
# 1067129 2020-12-20         4153                0.0        103.714286
#
#          Total Deaths  ...  metro_area  iso_3166_2_code census_fips_code  \
# 0                   0  ...         NaN              NaN              NaN
# 1                   0  ...         NaN              NaN              NaN
# 2                   0  ...         NaN              NaN              NaN
# 3                   0  ...         NaN              NaN              NaN
# 4                   0  ...         NaN              NaN              NaN
# ...               ...  ...         ...              ...              ...
# 1067125            48  ...         NaN              NaN           9015.0
# 1067126            51  ...         NaN              NaN           9015.0
# 1067127            51  ...         NaN              NaN           9015.0
# 1067128            51  ...         NaN              NaN           9015.0
# 1067129            51  ...         NaN              NaN           9015.0
#
#               date retail_and_recreation_percent_change_from_baseline  \
# 0              NaT                                                NaN
# 1              NaT                                                NaN
# 2              NaT                                                NaN
# 3              NaT                                                NaN
# 4              NaT                                                NaN
# ...            ...                                                ...
# 1067125 2020-12-16                                               16.0
# 1067126 2020-12-17                                              -57.0
# 1067127 2020-12-18                                              -11.0
# 1067128 2020-12-19                                                0.0
# 1067129 2020-12-20                                               -6.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 1067125                                              49.0
# 1067126                                             -52.0
# 1067127                                               5.0
# 1067128                                              16.0
# 1067129                                              11.0
#
#          parks_percent_change_from_baseline  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1067125                                23.0
# 1067126                               -49.0
# 1067127                               -20.0
# 1067128                                 NaN
# 1067129                                -9.0
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1067125                                         -26.0
# 1067126                                         -69.0
# 1067127                                         -35.0
# 1067128                                         -32.0
# 1067129                                         -29.0
#
#          workplaces_percent_change_from_baseline  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 1067125                                    -22.0
# 1067126                                    -68.0
# 1067127                                    -24.0
# 1067128                                      1.0
# 1067129                                     -1.0
#
#         residential_percent_change_from_baseline
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 1067125                                      9.0
# 1067126                                     30.0
# 1067127                                     13.0
# 1067128                                      6.0
# 1067129                                      5.0
#
# [1067130 rows x 26 columns]

# %% [markdown]
# ## PD7.4 Activity 8: Save County Data as Analytics Base Table

# %%
if using_Google_colab:
    df_abt_by_county.to_csv('/content/drive/MyDrive/COVID_Project/output/abt_by_county.csv')
if using_Anaconda_on_Mac_or_Linux:
    df_abt_by_county.to_csv('../output/abt_by_county.csv')
if using_Anaconda_on_windows:
    df_abt_by_county.to_csv('..\output\abt_by_county.csv')
