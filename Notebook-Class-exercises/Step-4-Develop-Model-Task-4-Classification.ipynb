# %% [markdown]
# ## Step 4 - Develop Model - Task 4. Classification

# %% [markdown]
# ###Load Libraries

# %%
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.0.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.19.5)

# %%
import pandas as pd
import numpy as np

from datetime import date
from datetime import timedelta

import matplotlib.pyplot as plt

from sklearn import preprocessing

from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score

from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ### Set up environment and connect to Google Drive

# %%
using_Google_colab = True
using_Anaconda_on_Mac_or_Linux = False
using_Anaconda_on_windows = False

# %%
if using_Google_colab:
    from google.colab import drive
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## DM4.1 - Open Notebook and sample LA county from Analytics Base Table, compute monthly differences - Activity 1

# %% [markdown]
# ### Upload State level Data

# %%
if using_Google_colab:
  abt_by_county = pd.read_csv('/content/drive/MyDrive/COVID_Project/output/abt_by_county.csv',
                              index_col=['Date'], parse_dates=['Date'])
if using_Anaconda_on_Mac_or_Linux:
  abt_by_county = pd.read_csv('../output/abt_by_county.csv',
                              index_col=['Date'], parse_dates=['Date'])
if using_Anaconda_on_windows:
  abt_by_county = pd.read_csv(r'..\output\abt_by_county.csv',
                              index_col=['Date'], parse_dates=['Date'])
abt_by_county
# Out:
#             Unnamed: 0  ...  residential_percent_change_from_baseline
# Date                    ...
# 2020-01-22           0  ...                                       NaN
# 2020-01-23           1  ...                                       NaN
# 2020-01-24           2  ...                                       NaN
# 2020-01-25           3  ...                                       NaN
# 2020-01-26           4  ...                                       NaN
# ...                ...  ...                                       ...
# 2020-12-16     1050091  ...                                       9.0
# 2020-12-17     1050092  ...                                      30.0
# 2020-12-18     1050093  ...                                      13.0
# 2020-12-19     1050094  ...                                       6.0
# 2020-12-20     1050095  ...                                       5.0
#
# [1050096 rows x 28 columns]

# %%
abt_by_county = abt_by_county.rename(columns={'retail_and_recreation_percent_change_from_baseline' : 'retail_recreation',
                                              'grocery_and_pharmacy_percent_change_from_baseline' : 'grocery_pharmacy', 
                                              'parks_percent_change_from_baseline' : 'parks',
                                              'transit_stations_percent_change_from_baseline' : 'transit',
                                              'workplaces_percent_change_from_baseline' : 'workplaces',
                                              'residential_percent_change_from_baseline' : 'residential'})
abt_by_county
# Out:
#             Unnamed: 0  Unnamed: 0.1  ...  workplaces residential
# Date                                  ...
# 2020-01-22           0             0  ...         NaN         NaN
# 2020-01-23           1             1  ...         NaN         NaN
# 2020-01-24           2             2  ...         NaN         NaN
# 2020-01-25           3             3  ...         NaN         NaN
# 2020-01-26           4             4  ...         NaN         NaN
# ...                ...           ...  ...         ...         ...
# 2020-12-16     1050091       1050091  ...       -22.0         9.0
# 2020-12-17     1050092       1050092  ...       -68.0        30.0
# 2020-12-18     1050093       1050093  ...       -24.0        13.0
# 2020-12-19     1050094       1050094  ...         1.0         6.0
# 2020-12-20     1050095       1050095  ...        -1.0         5.0
#
# [1050096 rows x 28 columns]

# %% [markdown]
# ### Filter data for LA County

# %%
abt_LA_county = abt_by_county[abt_by_county['County Name'] == 'Los Angeles County']
abt_LA_county
# Out:
#             Unnamed: 0  Unnamed: 0.1  ...  workplaces residential
# Date                                  ...
# 2020-01-22     1012688       1012688  ...         NaN         NaN
# 2020-01-23     1012689       1012689  ...         NaN         NaN
# 2020-01-24     1012690       1012690  ...         NaN         NaN
# 2020-01-25     1012691       1012691  ...         NaN         NaN
# 2020-01-26     1012692       1012692  ...         NaN         NaN
# ...                ...           ...  ...         ...         ...
# 2020-12-16     1013017       1013017  ...       -43.0        16.0
# 2020-12-17     1013018       1013018  ...       -43.0        17.0
# 2020-12-18     1013019       1013019  ...       -42.0        17.0
# 2020-12-19     1013020       1013020  ...       -22.0        11.0
# 2020-12-20     1013021       1013021  ...       -22.0         9.0
#
# [334 rows x 28 columns]

# %% [markdown]
# ### Calculate monthly summary of cases and force date to end of month

# %%
inc_cases_LA = abt_LA_county[['countyFIPS',
                              'Incremental Cases', 
                              'population']]
inc_cases_LA_month = inc_cases_LA.groupby(['countyFIPS'])['Incremental Cases',
                                                          'population'].resample('M').mean().reset_index()
inc_cases_LA_month['Month'] = inc_cases_LA_month['Date'] + pd.offsets.MonthEnd(0) 
inc_cases_LA_month
# Out:
#     countyFIPS       Date  Incremental Cases  population      Month
# 0         6037 2020-01-31           0.111111    10039107 2020-01-31
# 1         6037 2020-02-29           0.000000    10039107 2020-02-29
# 2         6037 2020-03-31          97.096774    10039107 2020-03-31
# 3         6037 2020-04-30         672.366667    10039107 2020-04-30
# 4         6037 2020-05-31        1026.258065    10039107 2020-05-31
# 5         6037 2020-06-30        1617.766667    10039107 2020-06-30
# 6         6037 2020-07-31        2740.387097    10039107 2020-07-31
# 7         6037 2020-08-31        1718.935484    10039107 2020-08-31
# 8         6037 2020-09-30         951.033333    10039107 2020-09-30
# 9         6037 2020-10-31        1203.838710    10039107 2020-10-31
# 10        6037 2020-11-30        3110.033333    10039107 2020-11-30
# 11        6037 2020-12-31       11137.550000    10039107 2020-12-31

# %% [markdown]
# ### Select Google Social Mobility data

# %%
google_LA = abt_LA_county[['countyFIPS',
                           'retail_recreation',
                           'grocery_pharmacy',
                           'parks',
                           'transit',
                           'workplaces',
                           'residential']]

# %% [markdown]
# ### Create Monthly summaries

# %%
google_LA_month = google_LA.groupby(['countyFIPS'])['retail_recreation',
                                                    'grocery_pharmacy',
                                                    'parks',
                                                    'transit',
                                                    'workplaces',
                                                    'residential'].resample('M').mean().reset_index()
google_LA_month['Original Month'] = google_LA_month['Date'] + pd.offsets.MonthEnd(0) 
google_LA_month
# Out:
#     countyFIPS       Date  ...  residential  Original Month
# 0         6037 2020-01-31  ...          NaN      2020-01-31
# 1         6037 2020-02-29  ...     0.000000      2020-02-29
# 2         6037 2020-03-31  ...    10.935484      2020-03-31
# 3         6037 2020-04-30  ...    22.166667      2020-04-30
# 4         6037 2020-05-31  ...    17.580645      2020-05-31
# 5         6037 2020-06-30  ...    13.833333      2020-06-30
# 6         6037 2020-07-31  ...    13.677419      2020-07-31
# 7         6037 2020-08-31  ...    12.129032      2020-08-31
# 8         6037 2020-09-30  ...    12.066667      2020-09-30
# 9         6037 2020-10-31  ...    11.129032      2020-10-31
# 10        6037 2020-11-30  ...    12.600000      2020-11-30
# 11        6037 2020-12-31  ...    14.150000      2020-12-31
#
# [12 rows x 9 columns]

# %% [markdown]
# ### Compute monthly difference

# %%
inc_cases_LA_month['Case Change'] = inc_cases_LA_month.groupby('countyFIPS')['Incremental Cases'].apply(lambda x: x - x.shift(1))
inc_cases_LA_month
# Out:
#     countyFIPS       Date  ...      Month  Case Change
# 0         6037 2020-01-31  ... 2020-01-31          NaN
# 1         6037 2020-02-29  ... 2020-02-29    -0.111111
# 2         6037 2020-03-31  ... 2020-03-31    97.096774
# 3         6037 2020-04-30  ... 2020-04-30   575.269892
# 4         6037 2020-05-31  ... 2020-05-31   353.891398
# 5         6037 2020-06-30  ... 2020-06-30   591.508602
# 6         6037 2020-07-31  ... 2020-07-31  1122.620430
# 7         6037 2020-08-31  ... 2020-08-31 -1021.451613
# 8         6037 2020-09-30  ... 2020-09-30  -767.902151
# 9         6037 2020-10-31  ... 2020-10-31   252.805376
# 10        6037 2020-11-30  ... 2020-11-30  1906.194624
# 11        6037 2020-12-31  ... 2020-12-31  8027.516667
#
# [12 rows x 6 columns]

# %%
google_LA_month['delta_retail_recreation'] = google_LA_month.groupby('countyFIPS')['retail_recreation'].apply(lambda x: x - x.shift(1))
google_LA_month['delta_grocery_pharmacy'] = google_LA_month.groupby('countyFIPS')['grocery_pharmacy'].apply(lambda x: x - x.shift(1))
google_LA_month['delta_parks'] = google_LA_month.groupby('countyFIPS')['parks'].apply(lambda x: x - x.shift(1))
google_LA_month['delta_transit'] = google_LA_month.groupby('countyFIPS')['transit'].apply(lambda x: x - x.shift(1))
google_LA_month['delta_workplaces'] = google_LA_month.groupby('countyFIPS')['workplaces'].apply(lambda x: x - x.shift(1))
google_LA_month['delta_residential'] = google_LA_month.groupby('countyFIPS')['residential'].apply(lambda x: x - x.shift(1))
google_LA_month
# Out:
#     countyFIPS       Date  ...  delta_workplaces  delta_residential
# 0         6037 2020-01-31  ...               NaN                NaN
# 1         6037 2020-02-29  ...               NaN                NaN
# 2         6037 2020-03-31  ...        -21.150538          10.935484
# 3         6037 2020-04-30  ...        -27.082796          11.231183
# 4         6037 2020-05-31  ...          7.856989          -4.586022
# 5         6037 2020-06-30  ...          6.209677          -3.747312
# 6         6037 2020-07-31  ...         -3.080645          -0.155914
# 7         6037 2020-08-31  ...          2.258065          -1.548387
# 8         6037 2020-09-30  ...         -0.577419          -0.062366
# 9         6037 2020-10-31  ...          3.609677          -0.937634
# 10        6037 2020-11-30  ...         -2.576344           1.470968
# 11        6037 2020-12-31  ...         -0.383333           1.550000
#
# [12 rows x 15 columns]

# %% [markdown]
# ## DM4.2 - Shift social mobility data by month and merge with cases data, convert monthly change to a qualitative difference

# %% [markdown]
# ### Shift google data by one month

# %%
google_LA_month_lagged = google_LA_month
google_LA_month['Month'] = google_LA_month['Original Month'] + pd.DateOffset(months=1) + pd.offsets.MonthEnd(0) 
google_LA_month
# Out:
#     countyFIPS       Date  ...  delta_residential      Month
# 0         6037 2020-01-31  ...                NaN 2020-02-29
# 1         6037 2020-02-29  ...                NaN 2020-03-31
# 2         6037 2020-03-31  ...          10.935484 2020-04-30
# 3         6037 2020-04-30  ...          11.231183 2020-05-31
# 4         6037 2020-05-31  ...          -4.586022 2020-06-30
# 5         6037 2020-06-30  ...          -3.747312 2020-07-31
# 6         6037 2020-07-31  ...          -0.155914 2020-08-31
# 7         6037 2020-08-31  ...          -1.548387 2020-09-30
# 8         6037 2020-09-30  ...          -0.062366 2020-10-31
# 9         6037 2020-10-31  ...          -0.937634 2020-11-30
# 10        6037 2020-11-30  ...           1.470968 2020-12-31
# 11        6037 2020-12-31  ...           1.550000 2021-01-31
#
# [12 rows x 16 columns]

# %% [markdown]
# ### Merge incremental cases and google DataFrames

# %%
merged_LA = pd.merge(inc_cases_LA_month, 
                     google_LA_month, 
                     on=['countyFIPS', 'Month'], 
                     suffixes=('', '_DROP'), 
                     how='inner').filter(regex='^(?!.*_DROP)')
merged_LA
# Out:
#     countyFIPS       Date  ...  delta_workplaces  delta_residential
# 0         6037 2020-02-29  ...               NaN                NaN
# 1         6037 2020-03-31  ...               NaN                NaN
# 2         6037 2020-04-30  ...        -21.150538          10.935484
# 3         6037 2020-05-31  ...        -27.082796          11.231183
# 4         6037 2020-06-30  ...          7.856989          -4.586022
# 5         6037 2020-07-31  ...          6.209677          -3.747312
# 6         6037 2020-08-31  ...         -3.080645          -0.155914
# 7         6037 2020-09-30  ...          2.258065          -1.548387
# 8         6037 2020-10-31  ...         -0.577419          -0.062366
# 9         6037 2020-11-30  ...          3.609677          -0.937634
# 10        6037 2020-12-31  ...         -2.576344           1.470968
#
# [11 rows x 19 columns]

# %% [markdown]
# ### Convert to categorical data

# %%
def convert_to_categorical(x):
    if x <= 0:
        return -1
    return 1

# %%
merged_LA = merged_LA.fillna(0)
merged_LA['case_direction'] = merged_LA['Case Change'].apply(convert_to_categorical)
merged_LA
# Out:
#     countyFIPS       Date  ...  delta_residential  case_direction
# 0         6037 2020-02-29  ...           0.000000              -1
# 1         6037 2020-03-31  ...           0.000000               1
# 2         6037 2020-04-30  ...          10.935484               1
# 3         6037 2020-05-31  ...          11.231183               1
# 4         6037 2020-06-30  ...          -4.586022               1
# 5         6037 2020-07-31  ...          -3.747312               1
# 6         6037 2020-08-31  ...          -0.155914              -1
# 7         6037 2020-09-30  ...          -1.548387              -1
# 8         6037 2020-10-31  ...          -0.062366               1
# 9         6037 2020-11-30  ...          -0.937634               1
# 10        6037 2020-12-31  ...           1.470968               1
#
# [11 rows x 20 columns]

# %%
merged_LA = merged_LA[2:]
merged_LA
# Out:
#     countyFIPS       Date  ...  delta_residential  case_direction
# 2         6037 2020-04-30  ...          10.935484               1
# 3         6037 2020-05-31  ...          11.231183               1
# 4         6037 2020-06-30  ...          -4.586022               1
# 5         6037 2020-07-31  ...          -3.747312               1
# 6         6037 2020-08-31  ...          -0.155914              -1
# 7         6037 2020-09-30  ...          -1.548387              -1
# 8         6037 2020-10-31  ...          -0.062366               1
# 9         6037 2020-11-30  ...          -0.937634               1
# 10        6037 2020-12-31  ...           1.470968               1
#
# [9 rows x 20 columns]

# %% [markdown]
# ### Save Intermediate results

# %%
merged_LA.to_csv('/content/drive/MyDrive/COVID_Project/output/merged_LA.csv')

# %% [markdown]
# ## DM4.3 - Develop decision-tree with all 6 mobility parameters for LA county

# %% [markdown]
# ### Prepare and apply the model

# %%
y_LA = merged_LA['case_direction'].values
X_LA = merged_LA[['delta_retail_recreation', 
               'delta_grocery_pharmacy', 
               'delta_parks', 
               'delta_transit', 
               'delta_workplaces', 
               'delta_residential']].values
X_LA
# Out:
# array([[-2.31311828e+01, -2.47311828e+00, -3.18365591e+01,
#         -2.74172043e+01, -2.11505376e+01,  1.09354839e+01],
#        [-3.07021505e+01, -2.02602151e+01, -2.49967742e+01,
#         -2.51161290e+01, -2.70827957e+01,  1.12311828e+01],
#        [ 6.02473118e+00,  9.96989247e+00,  2.60935484e+01,
#          8.63225806e+00,  7.85698925e+00, -4.58602151e+00],
#        [ 1.17086022e+01,  1.63010753e+00,  9.93978495e+00,
#          5.43440860e+00,  6.20967742e+00, -3.74731183e+00],
#        [ 1.93655914e+00, -1.72043011e-02,  1.93118280e+00,
#         -1.56344086e+00, -3.08064516e+00, -1.55913978e-01],
#        [ 8.06451613e-01, -1.64516129e+00, -5.80645161e-01,
#          1.12903226e+00,  2.25806452e+00, -1.54838710e+00],
#        [ 7.90322581e-01, -1.40430108e+00, -9.25053763e+00,
#         -1.19892473e+00, -5.77419355e-01, -6.23655914e-02],
#        [ 8.22580645e-01,  7.26881720e-01, -2.94301075e+00,
#          3.45698925e+00,  3.60967742e+00, -9.37634409e-01],
#        [-1.62258065e+00, -1.12688172e+00, -8.02365591e+00,
#         -5.59032258e+00, -2.57634409e+00,  1.47096774e+00]])

# %%
y_LA
# Out:
# array([ 1,  1,  1,  1, -1, -1,  1,  1,  1])

# %%
decision_tree = DecisionTreeClassifier()
model_LA = decision_tree.fit(X_LA, y_LA)

# %% [markdown]
# ### Following function may not work correctly in Anaconda. Try Google Colab if having problem in Anaconda

# %%
 plt.figure(figsize=(17,8))
 tree.plot_tree(model_LA, max_depth=2)
 plt.show()

# %%
print(decision_tree.feature_importances_)
# Out:
# [0.         0.         0.35714286 0.         0.64285714 0.        ]

# %% [markdown]
# ## DM4.4 - Develop decision-tree  with all 6 mobility parameters for all counties

# %% [markdown]
# ### Calculate monthly summary of cases and force date to end of month for all counties

# %%
inc_cases = abt_by_county[['countyFIPS',
                           'Incremental Cases', 
                           'population']]
inc_cases_month = inc_cases.groupby(['countyFIPS'])['Incremental Cases',
                                                    'population'].resample('M').mean().reset_index()
inc_cases_month['Month'] = inc_cases_month['Date'] + pd.offsets.MonthEnd(0) 
inc_cases_month
# Out:
#        countyFIPS       Date  Incremental Cases  population      Month
# 0            1001 2020-01-31           0.000000       55869 2020-01-31
# 1            1001 2020-02-29           0.000000       55869 2020-02-29
# 2            1001 2020-03-31           0.225806       55869 2020-03-31
# 3            1001 2020-04-30           1.166667       55869 2020-04-30
# 4            1001 2020-05-31           5.741935       55869 2020-05-31
# ...           ...        ...                ...         ...        ...
# 37723       56045 2020-08-31           0.451613        6927 2020-08-31
# 37724       56045 2020-09-30           0.666667        6927 2020-09-30
# 37725       56045 2020-10-31           3.870968        6927 2020-10-31
# 37726       56045 2020-11-30           7.933333        6927 2020-11-30
# 37727       56045 2020-12-31           2.450000        6927 2020-12-31
#
# [37728 rows x 5 columns]

# %% [markdown]
# ### Select Google Social Distancing Data for all counties

# %%
google_all = abt_by_county[['countyFIPS',
                            'retail_recreation',
                            'grocery_pharmacy',
                            'parks',
                            'transit',
                            'workplaces',
                            'residential']]

# %% [markdown]
# ### For Google darta create monthly summaries

# %%
google_month = google_all.groupby(['countyFIPS'])['retail_recreation',
                                                  'grocery_pharmacy',
                                                  'parks',
                                                  'transit',
                                                  'workplaces',
                                                  'residential'].resample('M').mean().reset_index()
google_month['Original Month'] = google_month['Date'] + pd.offsets.MonthEnd(0) 
google_month
# Out:
#        countyFIPS       Date  ...  residential  Original Month
# 0            1001 2020-01-31  ...          NaN      2020-01-31
# 1            1001 2020-02-29  ...     0.200000      2020-02-29
# 2            1001 2020-03-31  ...     6.090909      2020-03-31
# 3            1001 2020-04-30  ...    15.863636      2020-04-30
# 4            1001 2020-05-31  ...    10.850000      2020-05-31
# ...           ...        ...  ...          ...             ...
# 37723       56045 2020-08-31  ...          NaN      2020-08-31
# 37724       56045 2020-09-30  ...          NaN      2020-09-30
# 37725       56045 2020-10-31  ...          NaN      2020-10-31
# 37726       56045 2020-11-30  ...          NaN      2020-11-30
# 37727       56045 2020-12-31  ...          NaN      2020-12-31
#
# [37728 rows x 9 columns]

# %% [markdown]
# ### Compute monthly difference for all data

# %%
inc_cases_month['Case Change'] = inc_cases_month.groupby('countyFIPS')['Incremental Cases'].apply(lambda x: x - x.shift(1))
inc_cases_month
# Out:
#        countyFIPS       Date  ...      Month  Case Change
# 0            1001 2020-01-31  ... 2020-01-31          NaN
# 1            1001 2020-02-29  ... 2020-02-29     0.000000
# 2            1001 2020-03-31  ... 2020-03-31     0.225806
# 3            1001 2020-04-30  ... 2020-04-30     0.940860
# 4            1001 2020-05-31  ... 2020-05-31     4.575269
# ...           ...        ...  ...        ...          ...
# 37723       56045 2020-08-31  ... 2020-08-31     0.354839
# 37724       56045 2020-09-30  ... 2020-09-30     0.215054
# 37725       56045 2020-10-31  ... 2020-10-31     3.204301
# 37726       56045 2020-11-30  ... 2020-11-30     4.062366
# 37727       56045 2020-12-31  ... 2020-12-31    -5.483333
#
# [37728 rows x 6 columns]

# %%
google_month['delta_retail_recreation'] = google_month.groupby('countyFIPS')['retail_recreation'].apply(lambda x: x - x.shift(1))
google_month['delta_grocery_pharmacy'] = google_month.groupby('countyFIPS')['grocery_pharmacy'].apply(lambda x: x - x.shift(1))
google_month['delta_parks'] = google_month.groupby('countyFIPS')['parks'].apply(lambda x: x - x.shift(1))
google_month['delta_transit'] = google_month.groupby('countyFIPS')['transit'].apply(lambda x: x - x.shift(1))
google_month['delta_workplaces'] = google_month.groupby('countyFIPS')['workplaces'].apply(lambda x: x - x.shift(1))
google_month['delta_residential'] = google_month.groupby('countyFIPS')['residential'].apply(lambda x: x - x.shift(1))
google_month
# Out:
#        countyFIPS       Date  ...  delta_workplaces  delta_residential
# 0            1001 2020-01-31  ...               NaN                NaN
# 1            1001 2020-02-29  ...               NaN                NaN
# 2            1001 2020-03-31  ...        -13.686022           5.890909
# 3            1001 2020-04-30  ...        -24.413978           9.772727
# 4            1001 2020-05-31  ...         10.381720          -5.013636
# ...           ...        ...  ...               ...                ...
# 37723       56045 2020-08-31  ...          2.365217                NaN
# 37724       56045 2020-09-30  ...          9.200000                NaN
# 37725       56045 2020-10-31  ...          0.727273                NaN
# 37726       56045 2020-11-30  ...        -10.822511                NaN
# 37727       56045 2020-12-31  ...          8.952381                NaN
#
# [37728 rows x 15 columns]

# %% [markdown]
# ### Shift all county Google data by one month

# %%
google_month['Month'] = google_month['Original Month'] + pd.DateOffset(months=1) + pd.offsets.MonthEnd(0) 
google_month
# Out:
#        countyFIPS       Date  ...  delta_residential      Month
# 0            1001 2020-01-31  ...                NaN 2020-02-29
# 1            1001 2020-02-29  ...                NaN 2020-03-31
# 2            1001 2020-03-31  ...           5.890909 2020-04-30
# 3            1001 2020-04-30  ...           9.772727 2020-05-31
# 4            1001 2020-05-31  ...          -5.013636 2020-06-30
# ...           ...        ...  ...                ...        ...
# 37723       56045 2020-08-31  ...                NaN 2020-09-30
# 37724       56045 2020-09-30  ...                NaN 2020-10-31
# 37725       56045 2020-10-31  ...                NaN 2020-11-30
# 37726       56045 2020-11-30  ...                NaN 2020-12-31
# 37727       56045 2020-12-31  ...                NaN 2021-01-31
#
# [37728 rows x 16 columns]

# %% [markdown]
# ### Merge Incremental cases and Google DataFrames

# %%
merged_all = pd.merge(inc_cases_month, google_month, on=['countyFIPS', 'Month'], suffixes=('', '_DROP'), how='inner').filter(regex='^(?!.*_DROP)')
merged_all
# Out:
#        countyFIPS       Date  ...  delta_workplaces  delta_residential
# 0            1001 2020-02-29  ...               NaN                NaN
# 1            1001 2020-03-31  ...               NaN                NaN
# 2            1001 2020-04-30  ...        -13.686022           5.890909
# 3            1001 2020-05-31  ...        -24.413978           9.772727
# 4            1001 2020-06-30  ...         10.381720          -5.013636
# ...           ...        ...  ...               ...                ...
# 34579       56045 2020-08-31  ...         -0.837945                NaN
# 34580       56045 2020-09-30  ...          2.365217                NaN
# 34581       56045 2020-10-31  ...          9.200000                NaN
# 34582       56045 2020-11-30  ...          0.727273                NaN
# 34583       56045 2020-12-31  ...        -10.822511                NaN
#
# [34584 rows x 19 columns]

# %% [markdown]
# ### Convert all counties data to categorical

# %%
merged_all = merged_all.fillna(0)
merged_all['case_direction'] = merged_all['Case Change'].apply(convert_to_categorical)
merged_all
# Out:
#        countyFIPS       Date  ...  delta_residential  case_direction
# 0            1001 2020-02-29  ...           0.000000              -1
# 1            1001 2020-03-31  ...           0.000000               1
# 2            1001 2020-04-30  ...           5.890909               1
# 3            1001 2020-05-31  ...           9.772727               1
# 4            1001 2020-06-30  ...          -5.013636               1
# ...           ...        ...  ...                ...             ...
# 34579       56045 2020-08-31  ...           0.000000               1
# 34580       56045 2020-09-30  ...           0.000000               1
# 34581       56045 2020-10-31  ...           0.000000               1
# 34582       56045 2020-11-30  ...           0.000000               1
# 34583       56045 2020-12-31  ...           0.000000              -1
#
# [34584 rows x 20 columns]

# %% [markdown]
# ### Save Interim results

# %%
merged_all.to_csv('/content/drive/MyDrive/COVID_Project/output/merged_all.csv')

# %% [markdown]
# ### Prepare and apply the model to all counties data

# %%
y_all = merged_all['case_direction'].values
X_all = merged_all[['delta_retail_recreation', 
                    'delta_grocery_pharmacy', 
                    'delta_parks', 
                    'delta_transit', 
                    'delta_workplaces', 
                    'delta_residential']].values
X_all.shape
# Out:
# (34584, 6)

# %%
y_all.shape
# Out:
# (34584,)

# %%
decision_tree_all = DecisionTreeClassifier()
model_all = decision_tree_all.fit(X_all, y_all)

# %%
X_all.shape
# Out:
# (34584, 6)

# %%
print(decision_tree_all.feature_importances_)
# Out:
# [0.14836819 0.13989973 0.05526236 0.07694427 0.46742768 0.11209776]

# %%
plt.figure(figsize=(20,15))
tree.plot_tree(model_all, max_depth=2)
plt.show()
